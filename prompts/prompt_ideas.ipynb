# %%
from openai import OpenAI
api_key = open("api_key").readline()
client = OpenAI(api_key=api_key)
import json
import requests
import tiktoken
def save_json(data, filepath=r'new_data.json'):
    with open(filepath, 'w', encoding='utf-8') as fp:
        json.dump(data, fp, indent=4)

def request_gpt4(messages, response_format=None):
    if response_format == "json":
        response = client.chat.completions.create(
            model="gpt-4-1106-preview",
            messages=messages,
            response_format={ "type": "json_object" },
        )
    else:
        response = client.chat.completions.create(
            model="gpt-4-1106-preview",
            messages=messages,
        )
    return response.choices[0].message.content
def get_embedding(text, model="text-embedding-ada-002"):
    enc = tiktoken.encoding_for_model(model)
    while len(enc.encode(text)) > 8191:
        text = text[:-100]
    url = 'https://api.openai.com/v1/embeddings'
    headers = {
        'Content-Type': 'application/json',
        'Authorization': "Bearer {}".format(api_key)
    }
    data = {
        "input": text,
        "model": model
    }
    res = requests.post(url, headers=headers, json=data)
    res = res.json()
    return res['data'][0]['embedding']

# %%
import glob
import json
from pprint import pprint
def get_division_dict():
    res = {}
    divisions = open('division_index.txt').readlines()
    for division in divisions:
        participant, index = division.split(' ')
        res["N"+participant] = index
    return res
division_dict = get_division_dict()

def divide_background_topics(transcript, division_index):
    questions = [transcript['content'] for transcript in transcript if transcript['speaker'] == '採訪者']
    division_question = questions[division_index]
    for index, message in enumerate(transcript):
        if message['content'] == division_question:
            division_index = index
            break
    background_messages = transcript[:division_index]
    topic_messages = transcript[division_index:]
    return background_messages, topic_messages

for transcript_file in glob.glob('../data/raw/transcript/json/*.json'):
    transcript = json.load(open(transcript_file))
    participant = transcript_file.split('/')[-1].split('.')[0].replace("_done", "")
    questions = [transcript['content'] for transcript in transcript if transcript['speaker'] == '採訪者']
    background_messages, topic_messages = divide_background_topics(transcript, int(division_dict[participant]))
    save_json(background_messages, f'../data/result/transcripts/{participant}_background.json')
    save_json(topic_messages, f'../data/result/transcripts/{participant}_topics.json')

# %%
def infer_questions(answer):
    messages = [
        # {
        #     "role": "system",
        #     "content": """You are an question inferer, you infer what questions are being asked based on the answers.
        #     You will be given an answer, please infer what questions are being asked.
        #     Reply in Traditional Chinese.
        #     """
        # },
        {
            "role": "system",
            "content": """
            你是一個訪談的記錄者，現在有一個受訪者的回答，但是沒有訪談者問的問題。你需要根據這個訪談的回答推斷出訪談者問的問題。
            請用問句回答，並以“問題：”開頭。
            """
        },
        {
            "role": "user",
            "content": "{}".format(answer)
        }
    ]
    return chatgpt(messages)
import glob
interviews = glob.glob('result/chunks/*.json')
all_important_questions = []
for interview in interviews:
    chunks = json.load(open(interview, 'r'))
    chunk_important_questions = []
    for index, chunk in enumerate(chunks):
        answers = [message['content'] for message in chunk if message['speaker'] == 0]
        question = infer_questions("\n\n\n".join(answers))
        print(index, question)
    print("====================================")

# %%
import glob
import json
from pprint import pprint
def cluster_question():
    interviews = glob.glob('../data/result/chunks/*.json')
    all_important_questions = []
    candidates = ['10個', '十個', '議題']
    for interview in interviews:
        chunks = json.load(open(interview, 'r'))
        chunk_important_questions = []
        print(interview)
        index = 0
        for chunk in chunks:
            # important_chunk_question = [message['content'] for message in chunk if message['speaker'] == 1][0]
            chunk_questions = [message['content'] for message in chunk if message['speaker'] == 1]
            for question in chunk_questions:
                if any([candidate in question for candidate in candidates]):
                    print(index, question)
                index += 1
            # chunk_important_questions.append(important_chunk_question)
        all_important_questions.append(chunk_important_questions)
        # pprint(chunk_important_questions)
        print("===================================")
cluster_question()

# %%
from pprint import pprint
import glob
# interview_files = glob.glob("result/chunks/*_N10.json")
interview_files = glob.glob("result/chunks/*.json")
chunk_embeddings = {}
for chunks_file in interview_files:
    chunks = json.load(open(chunks_file, 'r'))
    interview_id = chunks_file.split("/")[-1].split("_")[1].replace(".json", "")
    for chunk_index, chunk in enumerate(chunks):
        id = interview_id + "_" + str(chunk_index)
        answers = [message['content'] for message in chunk if message['speaker'] == 0]
        if len(answers) == 0:
            embedding = get_embedding("No content")
        else:
            answers = " ".join(answers)
            embedding = get_embedding(answers)
        chunk_embeddings[id] = {
            "id": id,
            "conversation": chunk,
            "embedding": embedding,
        }
save_json(chunk_embeddings, "result/chunk_embeddings/all.json")

# %%
import jieba
import chinese_converter
from collections import defaultdict
def remove_stopwords(text):
# read stopwords from stopwords-master/all.txt
    stopwords = open('stopwords-master/all.txt', 'r', encoding='utf-8').read().split('\n')
    stopwords+= ['说', '做', '讲', '东西', '真的', '事情', '是因为', '这件', '…']
    stopwords = [chinese_converter.to_traditional(stopword) for stopword in stopwords]
    tokens = [token for token in jieba.cut(text, cut_all=False) if token not in stopwords]
    tokens = "".join(tokens)
    return tokens

# %%
import glob
import json
interview_files = glob.glob("../data/result/chunks/v2_1029/*.json")
chunk_embeddings = {}
print(interview_files)
for chunks_file in interview_files:
    chunks = json.load(open(chunks_file, 'r'))
    interview_id = chunks_file.split("/")[-1].split("_")[1].replace(".json", "")
    for chunk_index, chunk in enumerate(chunks):
        id = interview_id + "_" + str(chunk_index)
        answers = [message['content'] for message in chunk if message['speaker'] == 0]
        print(answers)
        if len(answers) == 0:
            embedding = get_embedding("No content")
        else:
            answers = " ".join(answers)
            answers = remove_stopwords(answers)
            embedding = get_embedding(answers)
        chunk_embeddings[id] = {
            "id": id,
            "conversation": chunk,
            "embedding": embedding,
        }
save_json(chunk_embeddings, "../data/result/chunk_embeddings/1129/all.json")
# Out:
# ['../data/result/chunks/v2_1029/chunks_N1_background.json', '../data/result/chunks/v2_1029/chunks_N11_background.json', '../data/result/chunks/v2_1029/chunks_N14_topics.json', '../data/result/chunks/v2_1029/chunks_N3_topics.json', '../data/result/chunks/v2_1029/chunks_N9_background.json', '../data/result/chunks/v2_1029/chunks_N6_topics.json', '../data/result/chunks/v2_1029/chunks_N11_topics.json', '../data/result/chunks/v2_1029/chunks_N19_background.json', '../data/result/chunks/v2_1029/chunks_N18_topics.json', '../data/result/chunks/v2_1029/chunks_N16_background.json', '../data/result/chunks/v2_1029/chunks_N6_background.json', '../data/result/chunks/v2_1029/chunks_N8_background.json', '../data/result/chunks/v2_1029/chunks_N18_background.json', '../data/result/chunks/v2_1029/chunks_N17_background.json', '../data/result/chunks/v2_1029/chunks_N12_topics.json', '../data/result/chunks/v2_1029/chunks_N7_background.json', '../data/result/chunks/v2_1029/chunks_N5_topics.json', '../data/result/chunks/v2_1029/chunks_N17_topics.json', '../data/result/chunks/v2_1029/chunks_N10_background.json', '../data/result/chunks/v2_1029/chunks_N9_topics.json', '../data/result/chunks/v2_1029/chunks_N19_topics.json', '../data/result/chunks/v2_1029/chunks_N5_background.json', '../data/result/chunks/v2_1029/chunks_N10_topics.json', '../data/result/chunks/v2_1029/chunks_N7_topics.json', '../data/result/chunks/v2_1029/chunks_N15_background.json', '../data/result/chunks/v2_1029/chunks_N12_background.json', '../data/result/chunks/v2_1029/chunks_N2_background.json', '../data/result/chunks/v2_1029/chunks_N2_topics.json', '../data/result/chunks/v2_1029/chunks_N15_topics.json', '../data/result/chunks/v2_1029/chunks_N8_topics.json', '../data/result/chunks/v2_1029/chunks_N13_background.json', '../data/result/chunks/v2_1029/chunks_N3_background.json', '../data/result/chunks/v2_1029/chunks_N16_topics.json', '../data/result/chunks/v2_1029/chunks_N1_topics.json', '../data/result/chunks/v2_1029/chunks_N4_topics.json', '../data/result/chunks/v2_1029/chunks_N13_topics.json', '../data/result/chunks/v2_1029/chunks_N4_background.json', '../data/result/chunks/v2_1029/chunks_N14_background.json']
# ['我自己對於就是在，比如說像人文這部分，那還有就是以前的歷史事件比較會去專注啦，會去關注這樣，那其實像現在目前戶政那邊登記綠島的人口在3月份來講的話，總共大概4000多人快接近5000，像原住民的部分，大部分都是從因為工作到這邊，所以其實島上真正的原民都沒有了，你現在看到的數據資料，全部都是因為工作在這邊的原民。然後男生女生的比例來講的話，基本上都是各一半就2000多，在我自己自己有時候會遇到附近的大哥，那像現在來講，我們說一個整數5000來講好了，那到底幾分之幾是新居民？因為現在有很多的孩子，因為就學關係，他們就一定是回臺灣，然後可能遷戶籍到臺灣本島的就是學校，所以其實真正的數據來講，大概差不多2/3都是真的是新居民。', '早上工作的人啊，然後還有就是說，就算是曾經在這邊工作的人，他們也不見得會把戶籍遷走，因為方便他們就是比如說回來的時候船票的折扣，那些差蠻多的，所以實際上真正你看到人口有5000人，坦白講，那個5000真的不到一半是真正的居民，而且3所學校裡面的學生也是最準確，基本上一半以上全部都是新居民的小孩。一個班級像我兒子，他那班是9個的孩子，他們那個班還好，因為他畢竟是已經五年級了，所以他們班現在只有大概9個孩子裡面就有3到4個是新居民的小孩一進來的，所以那個比例其實蠻高的，國中也是國中生也是，所以其實像現在我覺得在針對一些議題來講的話。不能夠只是單純視為以前或者是島民的，應該不是主要的趨勢了，所以在這方面我覺得可以，換位思考，就是說你們想要問的東西，其實是剛好是轉捩點，你們進來這個時間點剛好是遇到了很大型，然後非常大規模，整個要轉型的時間這樣子，所以就看你們想要了解哪一部分。']
# 人文歷史事件專注會去關注那其實像現戶政登記綠島人口月份話總共4000多人快接近5000原住民大部分工作其實島原民沒了你現數據資料全部都是工作原民然男生女生比例話一半2000大哥那像現整數5000講好了幾分幾是新居民因為現孩子學關係回臺灣然遷戶籍臺灣本島學校數據新居民早上工作然後還工作不見戶籍遷走回來船票折扣差蠻人口5000坦白5000不到一半居民所學校裡面學生準確一半全部都是新居民小孩班級兒子那班孩子班還好畢竟是五年級了班現孩子新居民小孩一進比例蠻高國中國中生現議題話夠單純視島民趨勢了我覺換位思考想要問的轉捩點時間點剛了大型然大規模轉型時間這樣子想要一部分
# ['其實不外乎就是生計啦，比如說像嚮導來講好了，我覺得不管今天是因為什麼原因上島，其實最簡單的就是「住」這件事情對不對？哈，那其實島上有非常多空閒的控制的空間，然後包含就是老人家他們。，就算是有老房子，他的弟妹不清楚好了，也是沒有人居住，所以其實之前在某一個會議上面，其實我有跟公所那邊提到一個問題，就是說，其實臺灣很多地方都在做在地創生，可是他們卻可以有效的統計，整個島上或整個地區性到底有多少閒置空間，是可以讓上島的年輕人，或者是想要在這邊生活的，比如說公務員什麼的，他們有機會可以去做，就是租任這件事情，而不是說今天因為。市場也沒有完全飽和，住的部分沒有完全飽和。你自己在各個村子，你看還剩很多閒置空間，對不對？那如果今天有效地把它弄出來，不要講什麼房屋仲介好了。', '就甚至是說，村幹事這件事情，它可以有效地去公告說，如果你今天在這個地區，你想要找地方住，你可以變成是告訴他，你可以去找誰問，我覺得這個動作其實是幫了很多，就是想要上島人住這件事情解決，因為他們就是找不到地方住，所以相對是今天只要有土地的人，我們也不要管他是什麼目的好了，那現在這邊的人就會變成是，我不管今天是不是什麼的預定地，我不管今天是什么保育地好了，反正我就是有辦法去簽訂我，反正就是我把地租出去，所以為什麼這個島上的那個地價會一瞬間，你看短時間內整個做大標章你其實你看你，你可以去查那個實際登錄這個平臺你覺得發現到短短的5年內，原本的兩三萬的價格飆到12萬，那個不是說。今天是有什麼事件改變的事，而是這邊的在地居民，他們現在變的很聰明，他們真的也是靠外地人，就是新居民在生活，因為他們只要有地就好，然後那些老舊的民宿，他們也現在變像是直接翻倍的租借給就是上島想要做生意的人，所以瞬間像我們這個村子有很多就是。比如說寒暑假，或者是農曆過年或回鄉的那些大學的小孩，他們常常會跟我討論一個點，就是說阿姨說實在的，我們也不知道我們是什麼時間點有能力回來這個島，因為第一個，我們不見得每一個人都要從事觀光產業，可是到現在，目前的取向都視作觀光產業對。 就做黑手就是機車行，要不要就是潛水教練，要不然就是你今天可能有能力你有一個爸媽留給你的民宿，可是我們不想要做這些，我們沒有興趣，因為我們從小就在這個商業的模式裡面長大，有些人是厭倦的。那我們回來之後，說實在我們也沒能力買地，然後可能爸爸媽媽他們留下來的，可能阿公阿嬤留下來的產業，早就租給外面的人了，所以這個是一個很矛盾的點，就是他們都沒有去想到說，哪這些真正的島民回來的孩子，他們到底能做什麼？然後之前還有講說什麼，年齡老化嗎？所以有什麼長照的機構單位，然後他們也是很用心，想說那其實也沒有那麼難，就是我們有開放名額嘛。那你可以讓這些人來做這些事情。 那我就心裡想說，我們不要講離島好了這件事情，臺灣本島的人都不做了，所以你不能夠說把大家最不想做的工作，然後反而留給這個島要回來的年輕人有點本末倒置的，所以那個機制是有一點邏輯顛倒了，是特別開放這個說你們會來就可以做這個，他們做這樣。綠島現在目前有一個長照機構，在這裡，他們其實現在面臨就是說要做這個行業的人，他們也人力短缺，所以當時我丟出這個議題就是就業這件事情。', '他們講說哪有，可是我會覺得好好笑，就是說是，你們怎麼都會想說要說那種不要做的工作，才給留給那些要回島的居民吶，誰要回來做完全是零。', '如果說今天假設像你看為什麼那么多在地創生的案子，他們就是年輕人，他們自己可能去搞一個類似像文化歷史的東西，讓他們覺得說，我回來有意思，因為我可以做文創的部分，或者是說我今天可以把我以前阿公阿罵那些老宅怎麼把它換翻轉成是一個故事館或者類似那種的，我覺得這個才是吸引年輕人，他們會想要回鄉的，而不是說我今天回來是因為我在臺灣混不好嗎？我只能回來做這件事情，所以在……3年前我參加那個就是國發會來綠島這邊在做那個離島建設基金的會議的時候，他有邀請各方的人，那他們也玩了一個很有趣的遊戲，就是他們有用黑板，然後對每個人都有一個不同的顏色的點點，然後你就可以上去貼，你覺得你想要知道你想要大家去看見的綠島問題是什麼？其實那一場會議裡面，大家都在講民生，真的主要都是民生，比如說為什麼這個島上明明就是。有什麼農農會、平價中心，那政府都有補助這些，為什麼我們島民去那邊買東西買一根蔥兩根蔥，居然比我從臺灣本島運進來的還要貴，這種東西不用騙人吧？進貨單跟你實際上你那邊販售的價格，你一看就知道了，那明明就是公所什麼單位都有去做補助，為什麼我們自己島民的？居民去那些地方買東西，居然是比臺灣本島貴，這個為什麼都沒有人去調整，所以其實那一次的會議上，大家都在講這件事情，那你說什麼比如說像環境生態，藍海經濟的來講，其實那個東西臺南反而不是大家在意的。', '沒辦法改變什麼，而且重點是那個畢竟是可能2/3是在做那個，可是真正的島上的居民，有很多不是在做這個的。所以那個討論的那個點，其實只是把問題找出來，但是後續你看隔著這3年了，也沒有什麼機制去限制，說他們不能夠無預警的漲價，因為講比較諷刺一點，他們後半段就是你去評價中心買東西，他們上面很多東西是沒有寫價格的，早期是這樣喔，他們連那個麥克筆都不跟你講說這一包九層塔多少錢，因為你去秤的時候多少錢是稱的那個人說了多少就算，然後這個東西它有沒有過期，有沒有報廢也是裡面的人說了就算，那他把這些東西根本不是即期品的東西轉賣到哪裡去，沒有人知道。', '所以這個東西。 就是很奇怪，因為沒有一個共同機制去做監督。 然後他們就是標給誰，然後就是那個廠商永遠去佔那個位置，然後實際上我們都不會走進去那邊買東西，因為真的價錢太誇張了，然後還有就是一個平價中心。在遊客中心正對面那個是比較誇張的，因為農會我覺得他畢竟是一個私人的農會，他不是公家單位喔，他是私人的一個企業，所以他要這樣去弄，我覺得那個我們沒有話說，可是今天政府有補助，就是所謂的平價中心這件事情來講的話，他們還是可以用這種方式在做剝削居民對很誇張，很奇怪，所以為什麼？', '可能還會你看，我就回到昨天那個議題就是公船這件事情，其實如果島上它本身，它有一個生鮮的東西生鮮蔬果的單位，我們去那邊買東西去那邊叫菜，我們根本不用每天去那邊搬貨，不就是你今天上大量我們給你下單就好啦。我們不用這麼辛苦，也不會造就說今天港口那邊做堵塞嘛。', '就其實就是找源頭嘛。我們為什麼要用最辛苦的方式去去解決民生，是因為上面沒有幫我們想到，而且實際上就有一個單位在做這樣的執行，他是一個平價蔬果中心哎，結果反而是我們居民要到外面去採買，還要運回來，然後港口就是很亂，然後也不要講說今天港口光是你看學校的老師們或者學校公務員，甚至我們有的時候我們島民要出去好了，港口出來，請問哪裡我們可以停車？沒有哎。那個地方是居民要用的。', '為什麼都變成是接客人？然後大家把車卡在那？然後就是水泄不通。這個其實是第2層的問題，可是就沒有人敢去動。對，那你看那個堤防出來那一帶是公共停車場哎，那為什麼都變成一些特有的車行？他們去卡那個位這個也是很奇怪呀，這個機制也很奇怪，然後像包含保育區那些地方。為什麼他們可以蓋，你說他是私有地嘛，可是他是保育地，為什麼他們可以這麼大規模的蓋？你看這些都是問題，可是有人敢去突破嗎？ 真的沒有，所以我們只能夠從那些可能比較不會去，有什麼好像害誰怎麼樣的議題去講，但實際上這個都是環環勾結，因為它就是一個公開的地方。然後外面新來的講說天哪，連石朗浮淺區都有這麼多棟在蓋在那邊，那你不要跟我講保育區這件事情了，因為他也是一個很蠻代表綠島的，一個就是生態保育區嘛，他都可以蓋成這樣，那你跟我講說其他地方你再跟我講什麼生態那個，你不覺得只是講給自己笑嗎？對呀，你看現在那個連那個大白沙那邊旁邊他都整地了，但是這很奇怪，對呀，']
# 生計導來講好了我覺原因上島簡單「住那其實島多空閒控制空間然包含老人家老房子弟妹了沒有人居住會議公所提到臺灣地方創生卻統計島上地區性閒置空間上島年輕人想要生活公務員機會租任市場沒飽和住飽和村子還剩閒置空間它弄講什麼房屋仲介了村幹事它地去公告地區想要找地方住告訴找誰問我覺動作幫了想要上島人住解決找不到地方住土地目的了那現預定什么保育地好了反正辦法簽訂反正地租島上地價會一瞬間短時間標章去查登錄平臺發現短短的年原本兩三萬價格飆到12萬事件改變事居民變聰明外地人新居民生活然老舊民宿現變像是翻倍租借上島想要做生意瞬間村子寒暑假農曆過年回鄉大學小孩討論一個點阿姨說實時間點有能力回來這個島第一不見事觀光產業到現取向視作觀光產業黑手機車行潛水教練能力爸媽留給民宿想要興趣商業模式長厭倦回來說實沒能力買地然爸爸媽媽留下阿公阿嬤留下產業早就租給外面了矛盾的點沒想到島民回來孩子然講說年齡老化有什麼長機構單位然後他用心想沒難開放名額人來想講離島了臺灣本島了夠說不想工作然留給島要回來年輕人本末倒置機制一點邏輯顛倒了特別開放綠島現長照機構面臨行業人力短缺丟出議題就業講說我會好好笑想那種工作才給留給回島居民吶回來零假設那么創生案子年輕人搞類似文化歷史回來有意思做文創阿公阿罵老宅它換翻轉成故事館類似那種我覺才吸引年輕人想要回鄉回來臺灣混不好只能回來年前參加國發會綠島離島建設基金會議邀請各方玩了有趣遊戲有用黑板然後對顏色點點然貼想要想要見綠島一場議裡面在講民生民生島上明明有什麼農農會平價中心政府補助島民去買買一根蔥兩根蔥臺灣本島運進貴不用騙人進貨單販售價格了那明明公所單位補助島民居民地方買臺灣本島貴沒有人調整會議在講環境生態藍海經濟臺南在意沒辦法改變重點畢竟是島上居民討論那個點找出續隔年了沒機制夠無預警漲價講比較諷刺一點半段評價中心買沒寫價格早期喔連那個麥克筆講說一包九層塔錢秤錢稱了然它沒過期沒報廢了即期品轉賣沒有人奇怪機制監督然後他標給然廠商永遠佔位置然後實際走買價錢太誇張了然後還平價中心遊客中心正對面誇張農會畢竟是私人農會公家單位喔私人企業弄我覺沒話政府補助平價中心話方式剝削居民誇張奇怪還會回到昨天議題公船島上它它生鮮生鮮蔬果單位買東西去菜不用搬貨我們給下單不用辛苦造就港口堵塞找源頭辛苦方式解決民生幫想到單位執行平價蔬果中心居民外面採買運回來然港口很亂然後也講說港口看學校老師們學校公務員島民要了港口請問停車地方居民要用接客人然車卡然水泄不通層沒有人敢動堤防一帶公共停車場那為特有車行卡那個位奇怪機制奇怪然後像包含保育區地方蓋私有地保育大規模蓋有人敢突破只能夠從有什麼好像害議題去講實際上環環勾結它公開地方然外面新來講說天連石朗浮淺區多棟蓋我講保育區這件了蠻代表綠島生態保育區嘛蓋成講說地方講什麼生態不覺講給笑看現那個連白沙旁邊整地了奇怪
# ['為什麼有水電，我們先不要講這件事，為什麼他可以申請水電？也沒有水電，那些人怎麼蓋，所以這個就很可笑，就是其實很多矛盾的。', '而且它其實如果你們今天公部門不想要這麼開門見山哪，請問一下這些機制為什麼讓他們當初有辦法申請水跟電？他們有水跟電，他怎麼去蓋，就不會延伸這麼多的問題，不是嗎？我就一直這在這邊，這個島上我一直百思不得其解的，']
# 水電先講這件事申請水電沒水電蓋可笑矛盾它公部門想要開門見山請問機制當初辦法申請水跟電水跟電蓋延伸這在島上百思不得其解
# ['因為那個地目來講，他還算是私有地，那個什麼都是開發那個只是當時的都更的計劃。實際上沒有動到，可是我覺得那也不對，那至少地主要想盡辦法去做變更。不是每一件事情他都有一個步驟嗎？那像我們在這邊做這麼久，我們所有東西都是合法的，那我我其實有時候我想想，我就覺得我們好像笨蛋，因為我們正常繳稅，當初在做蓋房子的時候，我們一個申請到一個階段，我們才敢往上跑，可是現在不是欸，現在是大家非常的霸道，就是你講這麼多沒有用，因為這邊沒有法可以管，然後你去檢舉也沒用，因為一張單才4萬5萬，其實坦白講我繳繳就沒事了。縣政府那邊也不敢做什麼大動作，因為說實在的，你要有個拆遷大隊在這邊，你看那個成本多高，所以為什麼這些人會投機取巧的原因，也是因為他就是看準了嘛，臺東你都沒有這麼大規模的廠，那我在這邊說實在的，我有辦法去搞到那個店什麼的。對有沒有很好笑，是。', '所以我們是非常一個縮小的，那當然我們也不用說很絕望，因為就是因為待得夠久，看的夠透了，所以我們會去盡量去做我們可以做的事情，因為要不然真的你會去質疑，為什麼當初你要去……因為在臺灣本島，我說難聽一點，大家都吃像很難看，但是至少還會有那個界線在，至少我會保守一點點啦，至少我不會那么的，好像誒，很理直氣壯這樣。 但是這裡是。所以我們就盡量就是把頭轉向，然後去做，我覺得我們還可以去，慢慢慢慢去累積一些正好的東西的事情這樣子。 所以我們會比較在意的，就是可能學校方面教育方面這樣子，認為覺得對的事情就會出來，那其實扯到那些什麼派系阿政治，那種我們就覺得那個就蠻可笑的，因為坦白講現在這幾年的政治取向，它永遠都是那幾個人在輪，只是換了一個頭銜而已，可是再怎麼樣玩怎麼玩都是那些招數而已，所以不要去太覺得這間你投這張票可以代表什麼，我們是這麼覺得啦，對對對。', '大概是這個方面。']
# 目來講他還算是私有地開發更計劃沒有動我覺至少想盡辦法變更每一件步驟那像久合法實有想想好像笨蛋繳稅當初蓋房子申請階段才敢跑欸霸道你講沒有用沒有法然檢舉沒用一張單才萬萬坦白講我繳繳沒事了縣政府做什麼大動作說實拆遷大隊成本多高人會投機取巧原因看準了臺東沒大規模廠說實辦法搞店沒好笑縮那當然不用絕望得夠久看的夠透了盡量質疑當初臺灣本島難聽一點吃難至少還會個界線至少我會保守一點點至少那么好像誒很理直氣壯盡量把頭轉向然後去我覺我們還慢慢慢慢累積正好這樣子在意學校教育這樣子就會那其實扯派系政治那種蠻可笑坦白講現這幾年政治取向它永遠幾個輪換了頭銜玩玩招數太覺這間投這張票代表
# ['我來綠島的話，應該目前這樣說大概一年，一年半左右。 ', '當初的話是剛好工作就是。想要就是給自己放一個暑假，工作到一個ending， 然後想要給自己放一個長假，然後就有點像skip year的方式啊。後來朋友剛好在遇到開店，因為其實8年前的時候在綠島打工換宿。對，然後我就朋友在這裡開店，然後就想說，過來這邊幫他們，就一待就是一整年，對就一待就是一整個一整年。 ', '我之前是在背包客棧，在民宿工作，然後後面就決定要留在這個島上。所以就開始去尋覓，開始找找房屋。然後就決定說，哎，剛好選中了，溫泉這一塊對。我的故事來源是這樣。', '對但是不太一樣，就是小幫手，對於就是在做民宿上面的工作，但是比較像是管家，因為我後面就是其實也比較強，因為你又開始在領薪水，所以就會比較偏向於管家的那份工作。對，但是因為我一直都是臺灣本島跟綠島一直來回兩邊一直跑一直跑，對就是後來還是有點有一些工作還沒有處理完，所以還是得回奔跑，所以就是不是一個正職的方式，但是反正就是前前後後，在這裡應該是待了整個年度吧，然後加上冬天我又要整理房子，所以真的是一整年都待在這裡。', '在整理這一間，所以都待在這個地方。', '其實真的是一個機遇，尤其是我一開始沒有想過說會選那麼遠，因為畢竟朋友都在南寮中寮，但是後來真的是南寮跟中寮，因為我不喜歡鐵皮，然後南寮跟中寮那邊在往柴口跟風玩還沒去看過去是一大片，現在現有的房子要麼就是空地，要麼就是鐵皮或者是貨櫃。 然後後來這樣，剛好朋友介紹就是這邊當地的一個大姐姐幫我介紹了這一間，然後一看了之後就是真的是很獨特，因為就是水泥房，後來就決定說好，就當下就當下就決定說要租下他了，所以我覺得其實只有思考一天，我就決定要租下來。 然後就開始以前在這裡沒有那麼的看起來這麼這麼的OK，因為那時候因為是一個獨居老人，對以前雜貨店的阿伯，在這裏它算是獨居，然後後來要轉租給工人，所以說這個過程中就是房屋，其實外觀看就是OK，但內部的空間是非常的髒亂，整個我說我覺得非常的髒亂，然後一點一滴的就是把它全部煥然一新，變到現在是敢住人。因為一開始真的很進來都不太敢進來。', '我當時就住南寮，所以我是南寮溫泉過來。', '對，但其實對綠島人來講這個是比較，這是很遠的距離，但是對臺東、對我們這種外地來的人其實是還好，因為就是市區到就是有點像富岡漁港到火車站的，呃不對，到市區的距離就這樣子就15分鐘而已。但是對綠島人因為綠島，真的是太方便，就是可能你走路3分鐘就到達親戚家了，走路5分鐘就到一個地方了，然後但是溫泉就是真的比較遙遠，但對觀光客來說，他們不會覺得溫泉是遙遠的地方。大家環島，一定會過這裡，所以就覺得嗯，也還好啦，對呀，就習慣。']
# 我來綠島話一年一年半左右當初話工作想要放一個暑假工作ending然想要放一個長假然後就skipyear方式朋友開店年前綠島打工換宿然後我朋友開店然後就想幫一待整年一待一整整年背包客棧民宿工作然後後面留在島上尋覓找找房屋然後就選中了溫泉這一塊故事來源不太一樣小幫手民宿工作像是管家我後面較強在領薪水偏向管家那份工作臺灣本島綠島回兩邊跑跑工作還沒有處理完回奔跑正職方式反正前前了年度然冬天整理房子整年整理這一間地方機遇一開始想過說會選遠朋友南寮中寮南寮中寮喜歡鐵皮然後南寮中寮柴口風玩還沒去看過大片現有房子空地鐵皮貨櫃然後後來朋友介紹姐姐幫介紹了這一間然後一了獨特水泥房租下了我覺思考租下然後就OK獨居老人雜貨店阿伯裏它算是獨居然後後來轉租給工人過程中房屋外觀OK內部空間髒亂髒亂然後一點一滴它煥然一新變到敢住一開始不太敢住南寮南寮溫泉綠島人來講這是遠距離臺東外地還好市區富岡漁港火車站市區距離這樣子15分鐘對綠島綠島太走路分鐘達親戚家了走路分鐘地方了然溫泉遙遠觀光客來溫泉遙遠地方環島會過還好習慣
# ['我覺得是這裡的環境，就是這裡的天然的氣候，然後再加上工作的方式，因為我是真的蠻喜歡海的。然後放眼望過去3座小島蘭嶼真的是太遠了，而且蘭嶼非常的排外，但是綠島人他們不會排外，蘭嶼很排外。嗯，我去過蘭嶼，蘭嶼人非常排外，那在蘭嶼開店的話，其實也是困難重，。因為我就是有朋友也是在那裡開店，還有就是有聽他們講過一些故事，再加上蘭嶼距離也比較遠。但是我比較希望可以距離再近一點點吶，我一直都很想要在海島生活，然後這3座小島，小琉球變成是太擁擠了，真的是觀光勝地了，因為一年四季都可以都可以在那海域上面，所以說小琉球很多人。對那我就不會先把小球放進去，那蘭嶼跟綠島的話，蘭嶼太過遙遠，又加上說就是排外。然後，種種原因這樣加在一起之後，覺得綠島才是最舒服的綠島坐飛機15分鐘坐船50分鐘就可以到達臺東，那綠島這邊的人，綠島當地人，其實他們不會排外，他們不會排斥外來者，當然可能有時候還是會一些小衝突啊，什麼之類的，但是就是大家都是蠻團結的，因為前陣子發生了就是船公司的事件，大家也都是一起團結在一起，不管是外地人還是本地人，大家都團結在一起，那也是會互相幫忙，因為我目前認識的綠島人。我覺得都是就是憨人，就是人的很棒的對。然後加上溫泉，這裡又是鄉村，所以說我認識的更多更多的綠島當地人，那其實跟他們相處在一起的話，就是並不會覺得就是像蘭嶼這樣子的這樣子的方式，因為蘭嶼人，他們其實比較不喜歡外地人。', '呃，我有在蘭嶼待過一個月，也是去打工換宿啦，對待過一個月，那我覺得而且綠島海域其實可能是對這裡原本就有一個牽絆。因為我第一個換宿的地方就是在綠島，所以我就一直很喜歡綠島。 對，然後我一直印象深刻，就是那時候剛踏上島上第一次的時候，我就是因為我剛剛在大白鯊白沙灣下打工換宿，所以一定會騎那條公路，就看到這一片的景色，太漂亮，就左邊是山，然後右邊是海，然後又真覺得來到一個世外桃源。所以我至今到現在，我還是覺得我去過那麼多國家，然後也是去很多地方潛水過，然後，但是我還是覺得綠島海域真的很棒，可能是因為跟這裡有一點點一些關係在，所以我會覺得說我在這個地方是最舒服。', '我是臺南人。', '對對對他是我們就是慢慢的，就是因為我們要把戶籍就開始要遷來這裡對，因為我們開始是變島民，島民之後就是可以享用一些，就是交通上面的優惠，對那這樣子的話可以讓我們進出再更方便一點，尤其是為你把自己遷回來遷過來綠島已經一陣子了。', '但是我是台南人。', '其實我有想過今年冬天我其實是，因為我去年冬天是在島上，所以我今年冬天會有想要開個一陣子，我想要試試水溫，那其實最主要原因是因為我覺得冬天的時候在地人會更空閒下來對，所以我也希望說在就是可以趁這個時間可以跟在地人有一些聯繫，一些就是交流或什麼之類的。因為夏季的時候，基本上不會有太多，就是大家都都在忙對，就是不太可能會還過來這邊探訪，就是來帶你這邊喝咖啡或什麼之類的，但冬天在地人就已經開始沒有遊客了，他們只是變的很悠閒，就是他們的放假，那我也希望說，因為其實島上的店家確實大部分都是我們只有做夏季冬季都是休息，可做到10月之後是基本上你就不會看到店家在這裡。 對，那我就覺得說欸，那這樣子的話，可能綠島的一些在地的姐姐啊，或者是阿姨叔叔他們啊，可能會想要找一個地方喝個下午茶之類的，可能就沒有那個地方了。對，所以我就覺得說，或許我可以嘗試開一下下，但是當然想還是會想給自己放假，但就是剩餘的時間，假設我沒有要去給自己放鬆的時間，我會想要回來鹿港去開店。對那開店其實我知道，一定不會有太多的人，但是就是可以更緊密的跟這裡的人相處對，因為我們去年冬天就是這樣。 因為自己一個人在這裡，所以說確實就是因為這樣子，所以就是認識了非常多這在地的一些叔叔哥哥啊，然後大哥大姐他們就會蠻照顧我的，所以我覺得這是一個蠻可以跟在地人聯繫的一段時間。因為也不希望自己，因為既然你生活在這個島上就不希望自己像是很商業化，可能就真的是整個夏季待在這裡啊，冬季就直接走掉的那種感覺，還是希望可以跟這裡是有一個聯繫。']
# 我覺環境天然氣候然後再工作方式蠻喜歡海然放眼望過座小島蘭嶼太遠了蘭嶼排外綠島排外蘭嶼排外過蘭嶼蘭嶼排外蘭嶼開店話困難重朋友開店聽講過故事蘭嶼距離遠希望距離近一點點吶想要海島生活然座小島小琉球太擁擠了觀光勝了一年四季海域小琉球先小球放進那蘭嶼綠島話蘭嶼太過遙遠排外然種種原因加在一起綠島才最舒服綠島坐飛機15分鐘坐船50分鐘達臺東那綠島綠島排外排斥外來者小衝突蠻團結前陣子發生了船公司事件團結外地人本地人團結幫忙綠島我覺憨人很棒然溫泉鄉村更更綠島那其實相處話並不會像蘭嶼這樣子這樣子方式蘭嶼喜歡外地人蘭嶼待過月打工換宿對待過月綠島海域原本牽絆第一換宿地方綠島喜歡綠島然後我印象深刻候剛踏上島上第一次剛剛大白鯊白沙灣下打工換宿騎那條公路景色太漂亮左邊山然後右邊海然後又真覺世外桃源到現去過多國家然後也地方潛水過然綠島海域很棒一點點關係我會地方最舒服臺南人慢慢戶籍遷來變島民島民享用交通優惠這樣子話進出更一點遷回來遷過綠島一陣子了台南人想過今年冬天去年冬天島上今年冬天想要開個一陣子想要試試水溫那其實原因冬天地人會更空閒希望時間聯繫交流夏季太忙不太可能還過探訪帶喝咖啡冬天遊客了變悠閒放假希望實島店家確實大部分夏季冬季休息10月之後是店家欸這樣子話綠島姐姐阿姨叔叔想要找地方喝個下午茶沒地方了嘗試開一下下想想給放假剩餘時間假設沒去給放鬆時間我會想要回來鹿港開店開店太更緊密相處去年冬天確實這樣子了這在叔叔哥哥然大哥大姐蠻照顧我覺這是蠻聯繫一段時間希望生活島上希望像是商業化夏季冬季走掉那種感覺希望聯繫
# ['其實我最一開始想開是民宿啊。', '對，但是你民宿投入的資金成本太高了。那餐飲的話，餐飲相對好比較入手。 但是我自己有就是對餐飲沒辦法做到真的就是讓大人就是可以開店那種等級，我自己覺得啦，我覺得那個門檻可能就高一點之類。我覺得做好吃的食物是真的非常的非常的困難啊，之前對咖啡跟甜點原本就涉略，所以覺得說，那從這裡下手可能會比較簡單一點點對，那就是會開這些咖啡小館，其實我覺得只是完成自己一個小夢想啊，不奢求自己要賺多少錢，就是要可能像外面的人投資者看綠島，他們會覺得說哦，在這裡你可能一年之內要回本啊，是不是我其實沒給自己設下這麼大的目標。我只是覺得說就是完成自己一個小小夢想，親手打造一間屬於自己的小店，那就是慢慢開，然後慢慢的讓這間小店可以用故事一直這樣下去，對，所以我其實開店我都蠻隨緣的。 就是沒有那麼的我沒有那麼大的壓力來源，就覺得說好像一定要一直賺錢或什麼之類的，那就算沒有觀光客，所以其實認真說，我IG確實有在宣，就是有在經營，但是我沒有刻意的去宣傳自己。', '全部都是靠當地的店家或者是遊客，然後找到這個地方。因為這個地方也不像是大街上那麼好找，就很大街上真的是只要摩托車就可以到達這個地方，但是我這個地方是要經過一個轉彎，然後你可能要摩托車，這樣快速騎過，可能還看不到他。真的是要走慢下來走下來慢下來，但這也是我的初衷，也希望大家在擁擠的城市裡面，既來到小島，就不應該再這麼的匆忙，你應該悠悠哉哉地慢下來，然後可能可以鑽進巷弄之中，然後看看周圍的東西，然後尋尋覓覓，來到這間小店，對，所以我蠻希望說這個，這是我的初衷啦，也是我的理念，就是不會希望說這裡就是變成是可能是大家打卡經過而已，希望是真的可以讓大家感受到一點點的溫暖，在這個地方，然後找到平靜下來的心。這個打造這間小店的話，其實算是一個小小的夢想，所以開什麼樣類型的話，民宿是我因為我原本就之前有在做這份工作，所以說而且我很愛跟人家聊天。 所以說就覺得說哎，民宿會比較喜歡，但是因為民宿的資金真的成本太高了，就可能沒有辦法，所以比較可以開始下手，肯定是先從餐飲開始。', '綠島現在對我來說應該是一個家，因為我其實對家的定義，我沒有我對家的定義就是有一群家人，我覺得有一個可以相互扶持的家人，然後讓你感受到溫暖強壯，那對我來說，這就是一個家。對所以說，當我感覺每一次回到這裡，其實不會想要，或者是會很期待出島什麼之類的，我還好，我其實蠻enjoy就在這個地方，但是嘴巴裡會講講的好像好想放假，所以就是想放假，不是想要出島就是想要放假，但如果真的讓我一直在這個島嶼上的話，我覺得我也是可以一直這樣下去。我覺得真的就是蠻喜歡的啦，就是早上起來就會看到海，因為我真的很喜歡大海，然後也有天然的一些景色景觀以及認識這裡的很多很多的朋友，然後像家人一般的存在時候就會覺得，這裡算是另外一個家。']
# 一開始想開民宿民宿投入資金成本太高了那餐飲話餐飲好比入手對餐飲沒辦法大人開店那種等級我覺門檻高一點之類我覺好吃食物困難咖啡甜點原本涉略下手簡單一點點會開咖啡小館小夢想奢求賺錢外面投資者看綠島會覺一年之內要回本沒給設下目標小小夢想打造一間屬小店慢慢開然慢慢這間小店故事開店蠻隨緣沒壓力來源好像賺錢觀光客IG確實宣經營沒刻意宣傳全部都是店家遊客然找到地方地方像是大街好找很大街上摩托車就達地方地方轉彎然摩托車快速騎過看不到走慢下走慢下這也初衷希望擁擠城市既來小島不應匆忙悠悠地慢然鑽進巷弄之中然然後尋尋覓覓這間小店我蠻希望這是初衷理念希望打卡希望感受一點點溫暖地方然找到平靜心打造這間小店話算是小小的夢想開什麼樣類型話民宿原本這份工作愛跟聊天民宿喜歡民宿資金成本太高了辦法下手肯定先從餐飲綠島現家對家定義沒對家定義一群家人我覺相互扶持家人然後讓感受溫暖強壯家當我感覺回到想要期待出島還好實蠻enjoy地方嘴巴裡會講講好像想放假想放假想要出島想要放假島嶼話我覺我覺蠻喜歡早上海喜歡大海然後也天然景色景觀很多很多朋友然後像家人算是家
# ['呃，我覺得最大的困難應該是來自於工程這一塊，就是其實在這裡開店，你開了之後不會有說真的很多大的困難存在，但是在開之前會有很多很多的問題就類似說，就是這裡的師傅非常難找。是啊，對這裡的不太像本島，你只要有錢，你就可以馬上去做這件事情。但是這裡這師傅不會去管你，因為這裡真的太缺師父，那這裡的師傅也少，所以說就是有一點他們就會比較，就是你供不應求了，對，所以說你會會很難請到師父，那師傅來的話，如果你不懂的話，你就很容易被糊弄。', '其實不管水電啊木工啊，還是就都是一樣。 你可能要提前半年就跟他講說誒，不好意思，可不可以幫我在什麼時候要做這間房子。 對，就是要必須要很早，很早之前就要先去詢問這樣子。對呀，然後這過程中就可能會遇到很多delay啊或者是罷工啊，或者是', '是有可能的，所以可是我很幸運沒有遇到過啊。 只是我聽過很多朋友會這樣講過。']
# 我覺困難工程這一塊開店開了之後不會困難開很多很多類似師傅難找不太像本島錢馬這師傅不會太缺師父師傅少一點供應求了會會難請師父那師傅來話懂話糊弄水電木工提前半年講說誒不好意思可不可以幫這間房子很早很早先去詢問這樣子然這過程中delay罷工幸運過啊聽過朋友講過
# ['就是在綠島生活嘛，愛喝酒嘛啊。 就是可能睡過頭啊，然後想到要上來，就不要來上班。', '很常很常遇到那種我朋友就等著水電等了將近快2個月了，對呀，就是完全就是你要每天打要催他來，他可能有時候還不想來。對對，當然我沒有我就真的蠻幸運的，我的師傅都是有來的，但是過程中確實也是會遇到很多這個問題啦。', '都住在綠島居多，我們從臺東請來的話一定會比較好說話，但是成本一定會比較貴，你要幫他找住的。 對然後就會相對來講的話，可能會稍微貴一點點，而且他們的器材啊運進來啊，其實也是一筆一筆資金金額對，那我們這裡有很不方便的原因是因為我們的東西，我們人在溫泉，所以東西下在南寮，我們其實不太像是可能住在中寮或南寮的店家就可以馬上就可以回到綠島，我們還必須要南寮上來溫泉，又是一筆費用。所以費用加一加就是成本就很高啦。為什麼綠島店家的就是其實大家都說綠島消費是堪比臺北，這是我覺得算是蠻正常的，對因為綠島真的認真算，他的那個成本也比較貴，因為畢竟是我們從像從臺北好了，從臺北運下來到臺東，從臺東再送來綠島，再從綠島港口再送到各個店家，經過3個路程，所以說真的是三段運費。 所以說這樣算一算，其實。 我們的物價一定會比較高，一定會就是可能比南部啊高出來很多，所以這是蠻大的一個一個差異性啊，對呀。', '因為這個應該是最大開店最大最大的問題，其他我都可以自己克服。自己心裡的問題，自己心裡要克服啊，因為我自己是因為這些電視，我自己一個人弄的。所以你可能會少了很多可以陪伴的角色，以及就是可能可以在旁邊給你意見的人，因為畢竟很多東西就是你自己跟人家做決定，但是一人開店時，有一個人就是看你自己，你要自己承受這些東西，但你也可以自己享有一些自由，所以有好有壞，就看你怎麼選擇。 但是目前下來是消化消化掉了，所以就還可以，對呀。', '綠島其實沒有。綠島的當地的當地人是真的還蠻願意分享，因為他覺得就是大家一起，我之前問過啦就是，但是不是問那種很老很老的，是問比較稍微在年輕一點點的，他們就覺得說就是反正大家一起啊。 因為我們，我其實認真說，不會說就是今年綠島開那麼多家咖啡廳，但是我們也不會不去那間店，就是有錢，大家一起一起，那你去看各自經營怎麼樣對吧？因為喜歡一間店的話，一定我們一定會有第一印象，很喜歡這間店，喜歡那間店，喜歡這家店對，但是我們不會覺得說哦，你開咖啡廳就是跟我競爭，不會就還好。對，就是大家一起努力，那消費者願意去哪裡就去哪裡。而且綠島夏天的時候啦，是真的人潮非常的多，所以說其實真的也不會到說真的就是會互相搶生意這種。我們不會有這種想法，就覺得大家一起做。所以說，不管是這裡的人，這裡的在地人還是外來的在這裡開店的人，他們都會願意分享他們的經驗給我。 就是跟我講說就是誒，哪個地方要更好更好啊，什麼之類的對，所以就還蠻不錯的。就是這樣。']
# 綠島生活愛喝酒睡過頭然想到上班很常很常那種朋友著水電了快月了打要催候還不想沒蠻幸運師傅過程中確實住綠島居多臺東請話話成本貴幫找住對然相話稍微貴一點點器材運進一筆一筆資金金額原因溫泉東西下南寮太像是住中寮南寮店家馬回到綠島還必須南寮溫泉一筆費用費用加一加成本高綠島店家綠島消費堪臺北這是算是蠻綠島認真算成本貴畢竟是臺北好了臺北運下臺東臺東送綠島綠島港口送到店家路程三段運費算一算物價高南部高出這是蠻差異性開店克服克服電視弄會少了陪伴角色旁邊給意見一人開店時承受享有自由壞選擇消化消化掉了就還綠島綠島還蠻分享問過問那種老老問比較稍微年輕一點點反正綠島開多家咖啡廳那間店錢經營喜歡一間店話第一印象喜歡這間店喜歡那間店喜歡這家店開咖啡廳競爭還好努力消費者綠島夏天人潮搶生意想法地人外來開店分享經驗給講說誒地方更好更好還蠻不錯
# ['綠島交通、環境、土地、政府運作這跟我沒什麼相關，但是還蠻重要的，整體經濟。', '整體經濟是整個島應該是看個人的，能源應該是電力，因為人太多進來之後會有很多的缺電的問題，夏天一定會跳電，因為電力不夠要做核心要件。災害就跟醫療是有些有一些關係的對，因為醫療不夠的話，他這醫療不夠的話，其實是沒辦法。嗯，最後一個國內貿易。']
# 綠島交通環境土地政府運作這跟沒什麼相關還蠻整體經濟整體經濟島應看個能源電力人太多之後會缺電夏天跳電電力核心要件災害醫療關係醫療話這醫療話沒辦法最後一個國內貿易
# ['他一定會有補助，但是這些錢不可能，所以這個我不會選擇，這都跟政府有關係啊，就我知道他們如果有些人可以從他們兩個裡面拿到錢，但是我沒有辦法，因為我們簡單地就設定一個那個救護團體就可以申請很多錢了嘛。公有土地應該可以吧，因為它有些公有土地是可以做開發的，不是開發就是公有土地可能廁所，我們的廁所其實是還蠻少的，整個道理你環島起來的話。', '醫療工作的重要醫療跟交通。', '能源、土地。', '應該是這樣子哦。', '我們沒有交通有時候這邊的生病的時候，他這邊的醫生其實進來的，這些醫生其實都很好，但是我們就少量少數的幾個醫生，但是如果我們生病了，也說我們常常都需要到臺東去，那如果而且夏天，就是你也可以你綠島老人家也很多，那如果他突然間生了病後，每次要有些老人家他要生申請就是很緊張緊急的時候，我們那個過程像我上次我媽媽就生了病，然後很嚴重了，但是他整個流程大概需要2個小時。', '2個小時直升機才載出一次，那已經都太久了，如果這2個小時，那如果交通，他如果可以溝通的好，然後直升機，然後叫他跑的話，那就馬上就可以到外面，有些人是因為這就是在轉診這個過程就死掉了。所以如果是交通，交通不只船運，可能是空運也有。然後環境當然是人多的時候環境，我們垃圾量還蠻蠻多的啦就是很多人來進了島上，我們的我們民宿只是垃圾量比較少一點，我們……', '常常都會叫，客人就會帶環保杯，然後出去去買飲料幹嘛，所以就比較好了。能源當然是整個島民宿開得那么多，然後政府他不去管管制，有些有些私有地的，雖然他不是建地，但是他一直一直一直在蓋。']
# 會有補助錢選擇這都政府係兩個拿到錢沒辦法簡單設定救護團體申請錢了公有土地它公有土地開發開發公有土地廁所廁所還蠻少道理環島話醫療工作醫療交通能源土地這樣子交通生病醫生醫生少量幾個醫生生病了臺東去夏天綠島老人家間生了病每次老人家生申請很緊張緊急過程上次我媽媽生了病然了流程個小時個小時直升機才載出太久了個小時交通溝通然直升機然後叫跑話馬外面轉診過程死掉了交通交通只船運空運然後環境環境垃圾量還蠻蠻人來進了島上民宿垃圾量少一點客人帶環保杯然買飲料幹了能源整個島民宿開得那么然政府管制私有地建蓋
# ['有些會罰，但是你還是會罰發文就會回去。', '還是會蓋', '這細節就可能不太知道。這邊的頭頭就覺得沒關係，因為這個能源跟土地還有現在的土地越來越長，越來越長，我們在臺灣可能買的農地是以分來計算，綠島是以坪來計算，你們1分就是300坪，300坪可以大賣150萬，這邊呢？一坪就呃，如果假設1分300坪，這邊可能需要到1500萬，差10倍。', '有些會，有些沒有。', '可能沒辦法，因為這個他拆也是需要一項工程。', '它需要人，你這麼這麼大這麼大量對現在所有人都蓋了，會想著就跟蘭嶼一樣就地合法。']
# 會罰會罰發文回去蓋這細節不太頭頭沒關係能源土地還有現土地越來越長越來越長臺灣買農地分來計算綠島坪計算分300坪300坪大賣150萬一坪假設分300坪1500萬差10倍沒辦法拆一項工程它對現所有人蓋了會想跟蘭嶼合法
# ['大家想要，但是後面我覺得他們其實要稍微管制了。如果你是建地，那是OK，但是合法是什麼程序是正常的，但是有些不是。', '申請請電，然後到時候夏天真的會跳電。像去年好像有一兩次，去年人少那麼多有一兩次。', '所以他那邊已經有擴充的火力的機器。', '解決方法。', '我覺得我是小市民，沒有辦法。', '交通，現在交通公司像我們的交通船的是現在是私人的。Speaker1:', '沒講，沒講詐騙。', '如果說設定上算，你現在是講公船的議題啊，然後嗯，他們算出來不過，我是政府機關，我當然是會覺得設定公函出出來之後我要考量的能力有餵養這一步，養護這些小船需要人力多少錢？那我一年大概要賺多少錢才能開得過這一這個船？所以他們覺得是不行，但是以我們來看，如果你沒有設你沒做了公船。', '對，他就覺得我要養這一艘船，我有能力，然後如果我又沒有賺錢。', '所以他們就先設想，我沒有賺錢。', '小琉球他們，他們也是有做做公船出來。他們有兩艘呀。先一艘，但是我覺得哎，好像有賺錢，慢慢也有買一艘，然後我再買一艘。 對呀，所以他先要有人去執行。但是縣政府然後我是看新聞的啊，然後他們就覺得好像不劃算。', '但是我們是比較想要因為這樣稍微就是有公跟私2個人去去對的話比較不會，至少你私不開船的時候，你要有公船的時候我們就可以。', '運送綠島物資就可以公船來運送了。對呀，那綠島居民的漁獲量也可以公船去載運，不管這裡人觀光第一，其實那個漁獲量是第二，因為沒有魚的時候，綠島居民很多人還是靠 捕魚維生的。所以，如果交通船有公家船進來，是好的。', '而且你看醫療他如果做的時候，他是可以幫助就就醫藥就可以過去對。 我們就不用那麼緊急的，當然這一艘船不用太不用太大沒關係，它就是可以速度快一點，然後醫療夠他就可以剛好可以上去，然後就載出去，不然海巡的話。', '可以也是可以，但是他會比較應該是程序的問題哦，都是跑比較長的程序。']
# 想要面實要稍微管制了建地OK合法程序申請請電然後到夏天跳電去年好像兩次去年人少兩次經有擴充火力機器解決方法我覺小市民辦法交通交通公司交通船現私人Speaker1沒講沒講詐騙設定上算你現講公船議題然算政府機關設定公函出出考量能力養一步養護小船人力錢一年賺錢開得過這一船不行沒設沒了公船要養一艘船能力然沒賺錢先設想沒賺錢小琉球做做公船兩艘先一艘我覺好像賺錢慢慢買一艘然後我買一艘先要有人執行縣政府然後我新聞然後他好像不劃算想要稍微有公私話至少私不開船公船運送綠島物資公船運送了那綠島居民漁獲量公船載運觀光第一漁獲量沒有魚綠島居民捕魚維生交通船公家船醫療醫藥不用緊急一艘船不用太不用太大沒關係它速度快一點然後醫療夠然後就載海巡話他會程序跑長程序
# ['行政程序喔。其他人會選怎樣？', '反正我已經選了啊。']
# 行政程序喔其他人會選反正經選了
# ['重要在哪裡？', '垃圾也有還有就是蓋的問題啊，那當然是房子多出來之後當然是，垃圾這個因為就是污水的問題，我們環境跟污水是有關係的污水污水就下去之後就是髒東西。']
# 垃圾蓋那當然房子多出之後當然垃圾污水環境污水係污水污水髒東西
# ['那個沒有，現在他們做的是中寮，我現在公館這個路段，他有在做一個。', '他只是先把污水清理場應該會一層一層地做，但是它是只有做一個系統池，當水先流到這裡那裡。']
# 中寮我現公館路段先污水清理場應該會一層一層它系統池當水先流
# ['所以人那麼多，當然是就是洗澡水就好了，對呀，就是會有稍微壞影響到環境。', '目前還沒有。', '你會熱嗎？', '綠島比較有點其實應該可以設定啦，這個我們之前政府機關，它要想要做一個小型的焚化爐，上一任，這一任的上一任，但是他上一任選上的時候，他有他有提案說要做，但是他啟動應該是需要一定的就是一個焚化廠，他焚化爐他啟動需要他如果垃圾量不夠的話，他其實是賠錢的。']
# 洗澡水了稍微壞影響環境還沒有你會熱綠島設定政府機關它想要小型焚化爐一任一任一任一任選上提案啟動焚化廠焚化爐啟動垃圾量話賠錢
# ['他是已經十幾年的時間，所以當然是會比較多他如果蛋。', '但這不是他就是運送問題，如果現在臺東有焚化廠已經開了，如果我們的運垃圾運算量是每週每個月都正常的，垃圾量就運出去就是OK的，因為你每次出去都是有幾10噸幾10噸，那一天綠島至少垃圾量可能給你一個三五噸，可能他一次出去了，一次出去大概會有20噸。所以他一天的量，其實我們知道，如果是夏天會比較多啦，冬天就會比較少，所以他也是足夠量出去，如果是這個可以直接在台東燒，那我們綠島就不需要做這個。', '他當然要配合船船家一個禮拜只有兩次。', '之前是有運，但先近期我我沒有注意看到，因為我之前是我朋友，他們在做，嗯，他們幫我。', '如果你固定可以，但是建築廢棄會比較多。', '建築廢棄會比較慢一點，那些東西也不能少，那你只能有土地要把他埋起來，所以那當然建築住戶廢棄物，你知道嗎？木頭啊，其他的啊，然後水泥磚啊，就是對啊，他當然只能埋起來。', '所以臺灣的建築那木頭，它埋起來是應該是會腐化掉，所以時間長久的問題就是它會腐化掉，垃圾如果回收也可以做的話，回收是現在整個島內回收就做了之後沒不會賺到錢，所以沒有人會去做不賺錢的東西。但我不知道你出去你要是靠船運可以出去嗎？', '一次就是一個禮拜，然後它會有。不是每天哦，每天當然就是140噸。但是不是每一天，他如果運的時候，他大概會是……', '冬天沒有遊客當然就是……', '他們大概有兩臺的清潔垃圾車大概就會等於一台的量大小。但細節還是要問他們那。']
# 經十幾年時間蛋運送臺東有焚化廠經開了運垃圾運算量每週月垃圾量運OK每次幾10噸幾10噸綠島至少垃圾量給你三五噸了20噸量夏天冬天少足夠量台東燒綠島配合船船家禮拜兩次運先近期沒朋友幫固定建築廢棄建築廢棄較慢一點少只能土地埋起那當然建築住戶廢棄物木頭然水泥磚啊只能埋起臺灣的建築那木頭它埋起腐化掉時間長久它會腐化掉垃圾回收話回收島內回收了沒不會賺錢沒有人賺錢船運禮拜然後它140噸運冬天遊客兩臺清潔垃圾車一台量大小細節要問
# ['鄉公所的單位。', '年輕一點的還是？Speaker3:', '比較瘦，瘦的瘦，瘦的，我沒在那邊看過有女生啊。', '裡面煮的是女生阿', 'Speaker3:', '啊，真的啊，難怪我就是我是騎到想說你要給他的，我說對，結果他只算我1杯的錢，然後他什麼意思？哦就是你的，然後就送1杯錢，然後我就去買雞蛋糕。', '哦，你用2杯，然後再去算。', 'Speaker3:', '對啊，這我自己的啊，他不知道我阿，因為我不知道你要喝甚麼阿，我不知道喝什麼。沒事，沒事，你們忙你們忙。', '啊，沒關係，我們反正講這個。', '就很多妹阿都要回來啊。', '這年紀只能靠妹阿來生活，笑那麼開心阿。', '對。', '剛剛我講的就是。', '就能源，但是現在他們是足夠量那個，裡面也是有認識一些人，所以他們現在機械已經都有更新了，所以能量能源應該是如果到現在這樣子，小店家開始OK的啦不要太大的，如果山上有那個潤泰的總裁，他們如果要開的話，或許他們的電力就我們的電力就比較……', '還沒蓋，沒有蓋，還沒有蓋。', '所以觀音洞那邊，沒有到牛頭山。', '當然，他們的用量應該會比較大一點，他如果一次可以接個三五百人，三五百間的話。', '對呀。', '那三百間的量就就等於是大概，然後五百間的就等於一百間的民宿欸。', '還不確定，臺灣應該沒有他們之前有有說是要看。', '對，就是一直有規劃，他們就會太久。', '土地是有一些土地他是覺得是廁所的問題，他有廁所啦，因為工作比有些可以做，做出廁所出來後你就環島環一個島，可是你不會看到公共廁所。', '從這裡上去，就是那個觀音洞，然後你開開騎騎騎你到了那個朝日溫泉。', '就沒有，然後再來就回到了綠島綠島南寮漁港。', '大概是這樣子呃，其他沒有。哦，公有土地他可以做公共建設是還好，因為學校的也都有教，活動中心什麼都都是足夠。 停車場會比較少一點，公共土地如果跟南寮可以做個停車場出來，然後做到環境就是現在他要做環島，你知道嗎？', '嗯，然後他現在我們走了。那這個他現在要改掉防波堤這邊去。但蓋然後就會衍生一些生態的問題。 嗯，所以那次那南寮是可以登登南寮公有土地我不知道是有有沒有，如果有的話，他們可以讓客人們停車走進去哦，是比較就比較不會塞到。']
# 鄉公所單位年輕一點Speaker3瘦瘦瘦瘦沒看過女生煮女生Speaker3騎想要給只算杯錢然後他然後就送杯錢然後我買雞蛋糕杯然後再算Speaker3這我喝喝什麼沒事沒事忙忙沒關係反正講這個妹阿都回來這年紀只能靠妹阿來生活笑開心剛剛我講能源足夠量機械更新了能量能源到現這樣子小店家OK太大山上潤泰總裁要開話電力電力還沒蓋蓋還沒有蓋觀音洞牛頭山用量一點接個三五百三五百間話三百間量然五百間一百間民宿欸還不確定臺灣應沒規劃太久土地土地廁所廁所工作做出廁所出環島環一個島公共廁所觀音洞然開開騎騎騎了朝日溫泉沒然後再回到了綠島綠島南寮漁港這樣子公有土地公共建設還好學校教活動中心足夠停車場少一點公共土地南寮做個停車場然環境環島然後他走了他現改掉防波堤但蓋然衍生生態那次那南寮登登南寮公有土地沒話客人停車走不會塞到
# ['都沒有。', '交通醫療。']
# 沒交通醫療
# ['有啊，有些我有些朋友也是這樣。', '好朋友，我那個前面的有一些好朋友民宿潛水店教練也會啊，他環境保育啊。 這些其實這3個大部分的居民都還蠻在意的，交通、醫療。', '所以就後面的其他的住屋，大家都自己有些有房子的就是住屋，應該比較沒什麼困擾到。', '政府運作就算了，我就想怎麼講？好，這不用什麼講了你。', '政府運作就……', '滿意喔。', '不滿意。', '其實我們是做商人的，我們跟我們政府機關，我們家就沒有跟他們。', '交集。', '從總體經濟跟。', '未來。', '那個不是很好看。', '依現在這樣發展下去的話，會變成跟小琉球一樣。', '就是滿街的屋子，那時候滿街的，但是我們的人又不會像小琉球，因為他們交通真的比較方便，他就是20分鐘就20分鐘就來了，然後我們一定要來回，就是要2個多小時對，所以差別在這裡，我們因為我們是2個小時，他們是20分鐘，如果我們變成1個小時會有來回一班的話那就不一樣。因為船船隻它的速度，所以他可能你可以一天最大容量5000人，嗯，那如果它是變成30分鐘一艘。就是30分鐘，來回1個小時，那就增加1萬了就變一萬人，所以整個島就會非常多夏天的街上，如果是有大廉價的時候，5000人在街上，那一個地方就爆掉。我不能想像小琉球這麼小，然後他可以容納2萬人。', '但是他們真的是容納人到2萬人，所以就就還蠻誇張。我們這邊本來都是在大馬路旁邊再蓋房子，現在慢慢地跑到山上去了，我覺得現在已經……', '有在跑動。', '如果你坐船從遠遠的把你明天你回去的時候，你明天回去嗎？', '我就是說你再回頭看綠島一下，你會看到半山腰的地方，本來是綠色的綠衣的對，但是現在他變成紅土，那個範圍他挖掉了。', '慢慢的，很可能要蓋。', '對呀，然後。然後所有人會越來越多了，因為遊客進來，然後你會賺到錢的還是會賺到錢，不會賺到錢在這邊生活，他覺得這樣就夠了，還是會很大有些人還是會覺得，我在這裡這樣子，就算生活就夠了，有些人是想要在這裡生活的。', '我們大致上應該跟疫情前是不太一樣的，疫情前的時候是房子蓋比較少，疫情開始的時候，人潮基本所有人都一直進來。', '那海裡面的話，目前看來死傷比較還沒有到很嚴重。']
# 朋友朋友朋友民宿潛水店教練環境保育大部分居民還蠻在意交通醫療就後面住屋房子住屋沒什麼困擾政府運作了想怎麼講不用講了政府運作滿意喔不滿意商人政府機關家沒交集總體經濟未來好看依現發展話小琉球滿街屋子那時候滿街小琉球交通20分鐘20分鐘了然後我們要來回多小時差別個小時20分鐘時會回一班話船船隻它速度容量5000它30分鐘一艘30分鐘回個小時增加萬了變一萬人整個島夏天街上大廉價5000街上那一個地方爆掉想像小琉球然後他容納萬人容納人萬人還蠻誇張本來大馬路旁邊再蓋房子慢慢跑山上了我覺得現跑動坐船從遠遠明天回去明天回去回頭看綠島半山腰地方本來綠色綠衣紅土挖掉了慢慢要蓋然然所有人會越越了遊客然賺錢賺錢賺錢生活就夠了很大這樣子生活就夠了想要生活上應疫情前太疫情前房子蓋少疫情人潮所有人那海裡面話死傷還沒有
# ['燙就好了。', '珊瑚還好啦，就但是夏天來，如果有遊客多的時候他就踩到。', '但是這邊的到教練們都素質還蠻高。', '就只有我們在體驗潛水，對就是就是OK的。', '浮潛的地方，其實大概大部分的都我們可以讓客人踩的地方那些礁石礁石了，所以他不是珊瑚。']
# 燙了珊瑚還好夏天有遊客踩教練們素質還蠻高體驗潛水OK浮潛地方大部分客人踩地方礁石礁石了珊瑚
# ['美好的。', '可能是每個人存款裡面都很多很多錢。然後大家呃應該都可以在外面就想蓋個，像我自己美好的，但如果有一塊土地，然後不用太大，然後我可以接納像我這些都是租的，我美好的畫面當然是我自己有土地，拿那個房子合法房子，然後接待的客人。', '但是我的美好的那個房子說的價位會比現在還要高，然後就就就你相相對的，我可以接納30個人的時候，我收的錢是這樣子，那如果接到十幾個，然後就要做到最不用到最上層，當然中上層以上就好了，最上層的人比較不好服務。對就是跟我們的通票是大概一樣，環保的然後……']
# 美好存款很多很多錢然外面想蓋個美好一塊土地然不用太然後我接納租美好畫面土地房子合法房子然接待客人美好房子價位比現高然後就相相接納30我收錢這樣子接到十幾個然不用上層中上層了最上層不好服務通票環保然
# ['協助喔。', '我覺得從小開始，就是從小開始。這一些可能已經長大了，就你不可能沒有辦法對我做做出甚麼樣的要求，那如果可以就是盡可能環境課程可以久久讓跟兩個國小三個學校他們可以常常帶他們去，如果人權那邊你們你們在裡面可以講一些關於海的啦，主要是關於海的。如果海壞了，我們就是賺不到錢。綠島就很簡單，就只有海，如果真的是甚麼都看不到，其實所有人都賺不到錢，就就是遊客也不會進來，我來你綠島我看不到東西，我為什麼要帶你來這邊，那你可能就我想讓他們保育就是保育，要要做到好。']
# 協助喔我覺已經長了辦法做出甚麼樣盡環境課程久久兩個國小三個學校帶人權關於海是關海海壞了賺不到錢綠島簡單海看不到所有人賺不到錢遊客我來綠島看不到我為帶想保育保育
# ['大概只有兩成。', '有些人不太會，因為打魚的人打魚的人還蠻多的，要打魚的人要他不要去打魚不太可能，他就靠那個賺錢。']
# 兩成人不太會打魚打魚還蠻打魚打魚不太可能賺錢
# ['他不會去浮潛去打魚，但是他會去最危險的地方打魚。我們所看到的，如果有一天你有學到潛水的時候，你會看到他們去打的魚打魚的地方，其實我們都不能去。', '是危險的，潛水的地方是危險。所以但是他們去，但是他如果其實那邊如果不打的話，或許那些於還會到處亂跑，就我們浮潛區我們的所有人都看得到。', '珊瑚礁也有，但是你說他珊瑚礁，其實珊瑚礁有些還是黑潮關係就上來之後，很多魚群都會上來。但是這個說真的是打魚，只是這世界裡面小小大概是1/10000來，源頭不是我們這邊的。', '呃，就一次游一口氣下去，但是……', '但是可以讓他們從小，大人不太支持，但是小朋友我們可以稍微灌輸他一點觀念嘛。十個救一個也是救。', '可以盡量減少，不要再讓打魚這樣的你，你從小教育好之後，他們長大之後，他不會想去打魚，本來有10個人在打魚現在我小朋友有小小又長大了，他又打了，10個又增加5個，那就越來越多了。', '很多人打的時候，影響大。', '會，但不是不能限制你，不能去那個地方啊，有些還是偷偷會去。他找不到，有時候我就要去有魚的地方可以保育區裡面是很有魚的，就進去偷偷打一下。']
# 浮潛去打魚他會危險地方打魚學到潛水魚打魚地方危險潛水地方危險話還會處亂跑浮潛區所有人珊瑚礁珊瑚礁珊瑚礁黑潮關係魚群打魚世界小小10000源頭游一口氣大人不太支持小朋友稍微灌輸一點觀念十個救救盡量減少打魚教育長想打魚本來10魚現小朋友小小長了了10增加越來越了影響地方偷偷找不到有魚地方保育區裡面有魚偷偷
# ['活動可以啊。我覺得會去都是特定那些人啊，我會去了就可能你像貓一樣它是觀念跟我們是一樣的，就是他是外來的綠島居民。', '對他們就會想要去。', '但有些真正在跑。', '誘因。', '誘因救活動獎品什麼東西哦。但是這個獎品不能，你一定要到最後才能領，你不能一開始就給不行。', '抽獎，就要讓他們抽，不要讓所有人都有，就是有抽到就有。你可以有小禮物，但是你最大我會有設定幾個大獎。', '籤喔。', '你只要有一點小物品。', '沙拉油阿、生活用品那些都可以，但是有些真的是會為了那個東西去。', '這之前你們有辦那個海龜點點名就介紹海龜，關於海龜海龜有幾種海龜，那那有些人那種或許人家就比較有興趣。', '然後於總有什麼跟關於綠島像最近的珊瑚健檢項目健檢你是跟珊瑚是有關係的，然後健檢完之後我們就做一個報告，就這邊魚來我們現在噢，真的有比較少的，從去年我們看到的東西跟今年看到的東西不太一樣。那就這個，你就他們這件事。是有珊瑚健檢吧，對。', '哎，我沒有辦法，我沒有去，但是我知道，但它做完之後，他可以幫我。']
# 活動我覺特定我會了貓一樣它觀念外來綠島居民想要跑誘因誘因救活動獎品獎品領一開始就給不行抽獎抽所有人抽到有小禮物我會設定幾個大獎籤喔一點物品沙拉油生活用品了東西去辦海龜點點名介紹海龜關於海龜海龜幾種海龜那種興趣然總有跟關綠島珊瑚健檢項目健檢珊瑚係然後健檢完報告魚來噢少去年太事珊瑚健檢沒辦法沒它完幫
# ['龍蝦了，關於龍蝦也是要的，就是可以禁止這些龍蝦。我們就一定要設定多大才可以抓。']
# 龍蝦了關於龍蝦禁止龍蝦設定多大才抓
# ['就是巡守員，是比較重要一點的。', '但是其實之前很久大概10年前以後有巡守員，關於海裡面的哎，你看國外它可能可能就像你講的那個都設定就是做得很好，他可能他是海巡，他看著那些人，他是可以公權力的，你不行，你就不行啦，但綠島沒有內綠島就是。', '久而久之，他就跟……', '最喜歡的一張，這2張其中一張。', '其他拍的都差我一點。', '這個他是拍了夜景，他如果拍了早上的日出的時候就比較好一點，他前面有日出來比較好，這個是在燈塔的旁邊，是在這個地方拍出來的。']
# 巡守員一點久10年前以後有巡守員關於海裡面看國外它你講設定海巡公權力不行不行綠島內綠島久而久之最喜歡一張張一張拍差一點拍了夜景拍了早上日出一點日出燈塔旁邊地方拍出
# ['這天氣是(聽不清楚)*1:10:00，然後它燈塔也出來，它燈塔是照亮人指引的方向。所以才它沒有啊，它是在白天的時候。就是晚霞都進入了晚上對，所以他燈光慢慢的亮了，所以不管是船隻、謎迷途的人可能看著它就可以知道方向。 其他就還好。', '命名喔。', '我剛剛講的很好，我剛才講了什麼，我忘記了。命名喔。', '叫倒影，不要啦。命名就我就講說比較。', '等一下，來幫我命名。', '不會這樣剛好，你拿一個吃吃看。', '是不是這樣子剛剛好。Speaker1:', '很好吃哦。', '等下下，這個光其實不好。', '就是火燒雲。Speaker1:', '你是住在Morley那邊嘛，那等下有個東西可以麻煩你幫我拿他。', '這個光出來的時候，代表了颱風要來了，所以天氣即將改改變。Speaker1:', '今年就等待這個雲出現。', '你為什麼期待？', '期待是他出現之後，貨櫃不知道飛走幾個。Speaker1:', '你是想看那個颱風帳篷。', '沒有啦，他已經第一個收起來了。倒影就是有倒影的，之影就幾個字，隨便嗎？', '指引人的方向的地方。這7張你會選哪一張比較漂亮。', '喔，這樣子本來很多小好。Speaker1:', '根據老漢的。去年看了很多次，他本人是很台。', '就叫他光影吧。', '光裡面會有出現的倒影呢，光就指引著方向的地方。嗯，對反射出人的另外一面，反射出他的另外一面呢，不管人不管誰。', '最低的哼。拍出來啊，不是物體。', '物體所有地方都是有意涵的，他就是……。', '這是機密，政治犯機密的一個呃，不可磨滅的一個地方。因為他們畢竟他們走進來就會到這裡，那么他是象徵著守護神。他不是將軍岩的，他是一些關於他守護者公館村這個地方。', '應該他吧。', '他是公義BOT的，所以他如果能做得更好一點，我會覺得很好。其他都很有意涵的，就是比較自然的。當然他們倆個都在綠島不可或缺，擴建的話，那擴建又關係到環評，他如果我能把它做到更大，我們飛機就可以直接從。', '臺北下來。有些高端的他，臺北臺北下來的客人，他就可以直接就飛下來，不需要在那邊轉來轉去轉來轉去它，如果可以下來，你收他要2500客人都來回5000塊是願意的。', '對他用這個小長城，他就是這還蠻厲害的啦。嗯，因為你看人這樣子把它帶過去這裡興建起來，所以他是很辛苦的，而且它這地方前面是日出，所以他早上起來的就是很漂亮。然後它是可以看到它雖然是朝日溫泉，但是他沒有提到，如果可以把它在做得更好。可以讓客人花那個錢，然後進去泡那個溫泉，是等值的那個他是很成功的。']
# 這天氣聽1000然後它燈塔它燈塔照亮指引方向才它沒它白天晚霞了晚上燈光慢慢亮了船隻謎迷途看著它方向還好命名喔我剛剛講我剛才講了我忘記了命名喔倒影命名講說幫命名吃吃這樣子剛剛Speaker1好吃光其實不好火燒雲Speaker1住Morley麻煩幫光出代表了颱風要了天氣改改變Speaker1等待雲期待期待貨櫃飛走幾個Speaker1想颱風帳篷第一收起了倒影倒影之影幾個字隨便指引方向地方張選一張漂亮喔這樣子本來小好Speaker1老漢去年了台光影光裡面會倒影光指引方向地方反射出人反射出最低拍出物體物體地方意涵這是機密政治犯機密磨滅地方走那么象徵著守護神將軍岩守護者公館村地方公義BOT更好一點我會意涵自然倆綠島不可或缺擴建話擴建又關係環評我能它更大飛機臺北下高端臺北臺北下客人飛下轉來轉去轉來轉去它收2500客人回5000塊小長城這還蠻厲害這樣子它帶過這裡興建起辛苦它地方日出早上很漂亮然後它它朝日溫泉沒提到它更好客人花錢然後進泡溫泉等值成功
# ['人員不太足夠，但我想要他如果能綠島居民就把它，綠島鄉公所可以把它收回來。', '它是可以賺到錢的啊，如果把它做得更好一點，但就是這邊小朋友，你看蘭嶼就是有核料廠嘛，所以它會有供一個一年一個人會有多少錢，綠島沒有，綠島完全都沒有，沒有一個這個可以賺錢的地方。雖然他放了那個，對他們不好但是說真的，那個核廢料放的是應該是也是安全的，不然你放的是40、50年的，他們人得癌症的人不會比我們多啊。是嗎？小心。蘭嶼的人得癌症真的比我們多嘛？你聽過？綠島得癌症的真的超多。', '我們就是那個基地臺發射的訊號，中寮村最多。', '中華電信塔臺啊。', '還有那個泡溫泉那個煮雞蛋的地方，然後把它做得完善一點。他可以去考察別人，我們我們試圖講過很多次，他都可以做竹欄鐵欄可以直接讓客人直接放進去，那煮雞蛋的時候就很好。', '你看你看我這裡不會讓你那邊的，你有進去看過嗎？所以他那個籃子因為圓形，然後每個客人都是拿出所有教的民用大啊，然後製造完之後就丟掉，結果那如果是可以把它做成長型的客人，就可以直接放下去就就比較好一點。', '但是他說那個他沒有辦法再做。他就是東管處已經做好了，他們不能再在更改他。電子設備他本來是有很多的，但是現在他就把慢慢拆除掉，然後人員也比較少一點。 啊，費用是增加的，但是他的東西是沒有……']
# 人員不太足夠想要能綠島居民它綠島鄉公所它收回它賺錢它更好一點小朋友看蘭嶼核料廠它會供一年人會錢綠島綠島沒賺錢地方放了不好核廢料放放4050年癌症小心蘭嶼癌症聽過綠島癌症超多基地臺發射訊號中寮村中華電信塔臺泡溫泉煮雞蛋地方然後把它完善一點考察試圖講過竹欄鐵欄客人放進煮雞蛋看過籃子圓形然後每個客人拿出教民用然製造完丟掉它做成長型客人放下去一點沒辦法東管處做好了更改電子設備本來慢慢拆除掉然後人員少一點費用增加沒
# ['所有帶著所有人的夢想的地方。', '你考試啊。', '環保杯啊。', '剛剛那個正妹拿給我的。', '鮭魚鬆，海的那一邊，你要吃嗎？', '可以啦。', '這個。', '對象徵的意義。', '你看他也是觀音嗎？', '跟這區息息相關的，然後觀音是綠島的信仰中心呢，或者是它就是就是很重要的一個角色。', '我喔？不會特地去看，但是我們每天都會去散步。', '我們會去人權了。買什麼菜？Speaker1:', '青菜，我們想吃青菜。', '時供沒青菜？', 'Speaker1:', '沒有，我想自己買青菜去燙，綠色的青菜，對阿我們去那邊買就好。', '地瓜葉喔。', '龍鬚菜，最好最好拿兩個。Speaker1:', '長怎樣？我沒有跟你講我之前查過胖起來就是她說不想要雜草。', '哼，帶她去採田菠菜。', 'Speaker1:', '你覺得我真的會採對嗎？', '其實它兩個是可以一起的。', '沉睡的船喔，沒有啦。', '甦醒中的巨人。', '現在人群去越來越多，它慢慢的慢慢的在醒來了。', '會越來越醒，他到時候會長大。', '那怎麼樣？', '是不至於到怎麼樣，但是空間應該我們的範圍其實還蠻大的，所以不會到很誇張啦。 因為該蓋的到時候，該蓋的就蓋滿，蓋的可能就會從這一區，然後往下一直去，那你看這一區公館村大概也都滿了，所以土地越來越少。']
# 帶著所有人夢想地方考試環保杯剛剛正妹拿給鮭魚鬆海吃對象徵的意義觀音這區息息相關然後觀音綠島信仰中心它角色喔特地去散步人權了買什麼菜Speaker1青菜想吃青菜時供沒青菜Speaker1想買青菜燙綠色青菜買地瓜葉喔龍鬚菜兩個Speaker1長沒你講查過胖起想要雜草帶採田菠菜Speaker1採對它兩個沉睡船喔甦醒中巨人人群越來越它慢慢慢慢醒了越來越醒會長空間還蠻誇張蓋該蓋蓋滿蓋這一區然後往這一區公館村滿了土地越來越少
# ['誰呀？不會壞掉，就是很任勞任怨，持續做自己的崗位。那家人也都做自己的事情，所以這樣子是認命的。比較不會改變，不像看著已經很多。就像綠島居民有土地有房子你只要有這個家就足夠，但是外面的人，他進來的時候，他看到哇。 這片土地比外面的很便宜，我就一直買，我有一這塊土地我賺了起來，然後我就去買買買，所以綠島土地真的是都被外來的綠島人……', '不是被當地的綠島人，像我是當地的綠島人。', '我就我租的，但是我覺得我這樣子就足夠了，我就沒有我就覺得足夠了，但是外面的人進來好像……', '我就覺得足夠，他覺得我需要一直賺錢賺錢，綠島差別在這裡，所以說好說傻就是比較少，就是我們就那種傻傻做事起來。', '這張直接去儲值喔。', '欸我們賺到500塊。']
# 不會壞掉很任勞任怨持續崗位家人這樣子認命改變不像看著綠島居民土地房子家足夠外面這片土地外面便宜買這塊土地賺了然後我買買買綠島土地外來綠島綠島綠島租我覺這樣子足夠了沒足夠了外面好像足夠他覺賺錢賺錢綠島差別傻少那種傻傻做事這張儲值喔欸賺500塊
# ['前五名喔？', '住屋是什麼？', '能源。大概因為你只有這些選項，這是四個最重要這個，這個還好，沒得選選這個。']
# 前五名喔住屋能源選項這是四個還好沒得選選
# ['對呀，因為政府是他……', '政府如果要強而有力去執行一件事情，他必須很懂得怎麼去運籌帷幄，怎麼去用各式各樣的方法去把這件事情完成。這個很重要，因為它有辦法去執行，這個我們未來才會有貢獻。']
# 政府政府要強執行一件懂得運籌帷幄各樣方法它辦法執行未來才貢獻
# ['算吧，臺東縣因為我們現在我們是鄉很小，那我們歸到縣政府管，那必須要縣政府強而有力的支援我，我們才會有資源，不然我們常常都是沒有資源的。像一直不斷地為什麼說政府運作很重要，我們有很多的東西。像之前早期我們一直在在講人工魚礁人工魚礁，老一輩的他不懂這個東西，他覺得說，你在海裡給我放一個東西會影響到。那我們現在這一輩的時代背景都不一樣，我覺得當背景不一樣的時候，像現在潛水人多。那我們一直在發展水域的觀光，那我們也想要做這兩個是我把這兩個講在一起就環境生態和政府運作這個很重要，你有人工魚礁你能有魚聚集，有魚聚集你才能有效的保護啊。不然這邊都是平的，魚也不會去聚在一起，那牠 游到別的地方也沒地方躲也是被打掉，那再來人工魚礁，他在觀光生計上面也有很大的幫助啊。它可以讓潛水員多很多個潛水點，就像國外的你像墨西哥坎昆，他們放一堆人像在水底，然後又被一個世界文化資產，這個其實都是政府可以去運作，不能因為即使我上次在海委會，我拜託過處長，其實我談到人工魚礁這一塊，他們的那種概念就是我上次在這裡被你們打槍一次，那以後就是等於沒有的，沒有機會。我覺得這個是很不對等不公平的，我認為很想跟他講，以前理事長不是我，以前是老一輩的。那我們現在有新觀念，新的思維，那看要怎麼做會會更好，這個是我覺得現在比較重要的事。那像交通交通就我們前兩天抗議的議題啊，這是我們綠島算島民的命脈，全部啊，遊客觀光，什麼都要靠它。那十幾年前，我們外港港區在建設的時候，他也不參考在地的意見，都不採納，蓋好了不能停。你又把問題丟回來給我們，不能停湧浪很大。然後把問題丟回來給我們，把問題丟回來給我們之後，你看造成這種擁擠啊，因為這裡就就不對嘛。', '不是，外港免稅店那裏。像這種問題，那我這我們這一代啊，你說我們這一代在不處理，那我們下一代還不是一樣？跟逃難一樣？ ', '所以這個是我覺得也很重要，那醫療本來這裡就不足，離島所以有很多的……，其實他如果港區重新規劃弄好，你包括那種100頓的現在海巡由100噸的。大型的船要進來我們這邊啊，以後有後送機制什麼都很快很方便，不怕風浪，現在港那麼小，我們很想，但是我們要不沒辦法，所以這些問題反映出來，其實他都是層層關卡，一個一個扣一個。', '進不來啊，我們沒地方讓他停泊。因為我們現在跟客船在塞一個碼頭，外港不能停，然後空間不夠，所以我一直在在吵這個東西。我說好不容易說政府有交通部，有有這個概念跟預算，說二類漁港要開始重新規劃設計，所以在這個上面，就要真的要好好的去聽聽我們的想法跟意見，要一次把它解決。']
# 算臺東縣鄉很小縣政府那必須縣政府強而支援才資源沒資源地為政府運作早期在講人工魚礁人工魚礁老一輩懂他覺海裡給放東西會影響這一輩時代背景我覺得當背景不一樣像現潛水人發展水域觀光想要這兩個這兩個講在環境生態和政府運作人工魚礁有魚聚集有魚聚集保護平魚也聚在一起游到地方沒地方躲掉人工魚礁觀光生計很大它潛水員多潛水點國外墨西哥坎昆放一堆人像水底然世界文化資產政府運作上次海委會拜託過處長談到人工魚礁這一塊那種概念上次打槍那以沒機會我覺公平想他講理事長老一輩新觀念新思維看要做會會更好覺得現事那像交通交通前兩天抗議議題這是綠島算島民命脈遊客觀光它那十幾年前外港港區在建設參考意見採納蓋了停丟回來給停湧浪很大然後把丟回來給丟回來給擁擠外港免稅店裏這我們一代一代下一代逃難那醫療本來離島港區規劃弄包括那種100頓海巡100噸大型船要以後有送機制很快風浪現在港想沒辦法層層關卡扣進不來沒地方停泊客船塞碼頭外港停然後空間吵好不容易政府交通部概念預算說二類漁港規劃設計好好聽聽想法意見它解決
# ['其實要看政府就是要看頭頭。 如何如何那個，看我們現場看我們的航港局，看我們這些上級的長官，他們有怎樣的想法，其實我們都有給他們建議跟想法，只是他們做與不做而已，大概是這樣。']
# 政府看頭頭現場航港局上級長官想法有給建議想法
# ['縣政府，臺東縣政府。', '然後花蓮航港局。', '港務局，他們就管這些客船啊。給他管理港口的一些事物的。', '對我們臺東屬於花蓮館。', '所以他們在意的所有後續的決策跟動作是很重要的。 他們要聽我們的意見會好一點，不聽我們的意見就是可能問題又造成了，又要我們來人民來收拾善後。 由我們來承受。', '中央吧，綠島太小了，在臺灣就就一個這麼小的島。人口才4000多人，所以中央永遠看不到我們這裡。我會去重視這個地方，他如果今天是到綠島，是全世界十大潛水聖地。那是不是該好好……，這裡是個國際性的地方，所以可以好好的把觀光把我們這些建設弄好。對呀，你們政府都撥很多錢做什麼做什麼做什麼，可是人就撥那個零頭，其實來到我們綠島就夠了，我們就港口就很漂亮。中央啊，要重視這個小地方，我講一個我講一句比較難聽的話，如果今天我們的這些中央政府這些總統啊什麼的，你們連一個小地方都照顧不好。連這麼一個小的地方都照顧不好，我講真的，你臺灣沒有一個地方照顧的好。你把所有的經費支援什麼全部都扔在大城市上面。 大城市它們不缺吧？不比我們缺吧？醫療也不好，交通也不好等等的問題都很多啊，真的我們要去要一個經費，我在漁會為什麼很難做，我們漁會很小。我要去要個經費，要個什麼都很難。', '對呀，對呀。政府有效地運作，他真的想要建設這個地方，其實是很快的很有執行力。可是他如果真的沒有想到我們這個地方，他是永遠不會被看到這個是很大的關鍵。', '能源，因為我們這裡是火力發電，那我當然希望有其他的能源可以替代。只是，這個我就因為我比較不懂，但是我知道綠島現在的電力公供應是不太夠的。', '而且現在越建越多，房子越蓋越大。他所需的用電量會很大，那以後也會不堪負荷，所以早一點要面對這個問題。']
# 縣政府臺東縣政府然後花蓮航港局港務局客船給他管理港口事物臺東屬花蓮館在意續決策動作聽意見一點聽意見了人民收拾善承受中央綠島太小了臺灣就小的島人口才4000多人中央永遠看不到我會重視地方綠島全世界十大潛水聖地好好國際性地方好好觀光建設弄政府撥錢撥零頭其實來綠島就夠了港口很漂亮中央重視地方講一個我講一句難聽話中央政府總統連一個地方照顧不好連這麼地方照顧不好我講臺灣沒有地方照顧經費支援扔大城市大城市不缺缺醫療不好交通不好經費漁會難漁會很小我要經費要個難政府地運作想要建設地方很快執行力想到地方永遠很大關鍵能源火力發電希望能源懂綠島現電力公供應不太夠越建越房子越蓋越大需電量很大那以不堪負荷早一點要面
# ['像泰國、馬來西亞、越南啦，他們每個潛點啦，可以潛水的聖地馬來西亞、西巴丹啦。他們都是政府在打形象廣告在做建設在做什麼在做限制，這裡是保護區，一天只能上島多少人，他們都有在做，這個只有我們臺灣的政府對綠島完全是……，從發展觀光20幾年，到現在一直保持現在這樣原樣，沒有什麼很大的改變，我自己在這裡長大，就沒有很大的改變。都是我們這些業者啦，我們這些慢慢的年輕人上來有一些不一樣的思維，自己在做自己在幹。', '像馬來西亞，他們會會比較常看到他們在打廣告啊。在在全世界的媒體有在我們的觀光、我們的神。那他們有在建設碼頭至大船可以停靠的他們是沙岸欸，我們還有漁港欸，他們都可以做到這樣了，為什麼我們的碼頭20幾年來都不會變，都是這樣，這個真的不是一個發展觀光該有的樣子。不是說我們是很刁民還是怎樣，一直要東西要東西啊，如果一次建設就沒人會吵你了。大家去過綠島，真的是一個國際的碼頭厲害。那你外國人，他們進來，遊客進來是舒服的。 不是要關在網子裡面，然後在那邊熱得要死，然後等等老半天。這個應該都是政府真的要去好好思考的問題。那海底，我們的海底很漂亮的。從龍王鯛事件開始，其實我們很多漁獵者漁獵的人，我們也是漁民，我常常在跟他們聊天啊。 我們潛水業者，我本身也有做潛水，我跟他們都保持了良好的關係，所以我可以在漁會，今天我在漁會這個位置，我可以當他們的橋樑。就可能他們已經被污名化了，但是我希望不能把他們污名化。所以他們也知道，這個什麼不能打，龍頭鶯歌，他們現在絕對不會打，還會回來跟我們回報，我在哪裡看到什麼東西，那我們潛水員就去看。所以這個就是一個很棒的交流，很好的交流，他這個概念已經慢慢的從聊天等等的過程中建立在他們的腦袋。我們鋼鐵礁有燕魚，但是他是只有鋼鐵礁保護區裡的燕魚，不能抓他，其他外面其他地方都有燕魚，但是他們不好意思。我今天在其他地方打了一條燕魚上來，他也會覺得我會不會被人家懷疑，他也不好意思。就類似這樣的概念，其實這這個東西已經在這幾年從龍王鯛事件後慢慢落實在他們', '的腦海裡。', '那我們都在人民都在慢慢的改變了，為什麼政府還是沒有動作？你要什麼還是要不到，說人工營銷破壞海底的生態，還是等等的問題？環評嗎？環保議題？ 什麼的？覺得這個不是很很大的原因。像以前放鋼鐵礁放電桿礁等等，你像看現在那個地方，反而變成一個生態區，變成潛水員的聖地。所以應該政府多朝這個方向去走，而且這個那地方有的還沒有保護喔，沒有畫在保護區裡面。', '但是這些人會知道這裡是潛水員在潛水，我們不要進去狩獵。久而久之，就會變成一種習慣。你要一昧地禁止要圍、要畫，我要畫多大的範圍，我要圍多大的範圍，誰理你？真的就是強制性的那個，沒有人會理你們，沒有人會理你怎麼圍啊，只會有抗爭而已。']
# 泰國馬西亞越南潛點潛水聖地馬來西亞西巴丹政府形象廣告建設保護區只能上島臺灣的政府對綠島發展觀光20幾年到現原樣很大改變這裡長沒很大改變業者慢慢年輕人不一樣思維幹像馬來西亞會會常看到打廣告全世界媒體觀光神在建設碼頭至大船停靠沙岸欸漁港欸了碼頭20幾年不會變發展觀光樣子刁民東西要建設沒人會吵了過綠島國際碼頭厲害外國人遊客舒服要關網子裡面然後在熱得要死然老半天政府好好思考海底海底很漂亮從龍王鯛事件漁獵者漁獵漁民聊天潛水業者潛水了的關係漁會漁會位置當他們的橋樑污名化了希望污名化龍頭鶯歌還會回來回報潛水員很棒交流交流概念慢慢聊天過程中建立腦袋鋼鐵礁有燕魚鋼鐵礁保護區裡燕魚抓外面地方燕魚不好意思地方了一條燕魚我會懷疑不好意思類似概念這這個這幾年從龍王鯛事件慢慢落實腦海裡人民慢慢改變了政府動作不到人工營銷破壞海底生態環評環保議題很大原因放鋼鐵礁放電桿礁看現地方生態區潛水員聖地政府多朝方向走地方還沒有保護喔沒有畫保護區人會潛水員潛水狩獵久而久之就會一種習慣一昧禁止要圍要畫我要畫多大我要圍多大誰理強制性沒有人會理沒有人會理圍只會抗爭
# ['對，這個其實像我在這個地方放了個就是人工魚礁什麼的，淺淺的地方我可以號召這些漁民來一起來幫忙，幹嘛幹嘛，那也給他們一個概念，這個地方是屬於大家的，魚未來有地方捕，你抓不到他捕 不到他，但是他們會在這里繁育下一代，他的下一代魚會越來越多，住不下會往外面去，這樣你們都抓得到，而且不會抓到小魚，一定都抓到大魚，要用這種概念去教他。綠島從我小時候到現在不是沒有，真的不是沒有。是有留區……，這這個真的要和你們要在這個地方久才就會知道。']
# 地方放了人工魚礁淺淺地方號召漁民來幫忙幹嘛幹那也給概念地方是屬魚未來地方捕抓不到他捕不到這里繁育下一代下一代魚會越來越住往外面抓抓到小魚抓大魚要用概念教綠島留區這這個和地方久才
# ['這個是其中一個方法，我剛剛有講了說，慢慢把一些年輕人輔導來抓迴游性魚類真的很棒，這很厲害。這個我們都有在做，其實都有。慢慢的在進步，但是你不能很快，你很快，那個衝擊度很大。但是久時間，久而久之，我們年紀會變大，體力會變差。 你要一口氣是去做這個漁獵的動作是不容易的，體力會負荷不了，可能說今天我就去打個2條，我們試一次而已就這樣，不是那我要去打了回來賣錢賣多少錢的概念。', '我爸現在就是這個概念，我只是去運動。你看他70歲了，你叫他不下海，他馬上就生病。', '對。', '他還是一樣70歲。', '所以我說這個東西真的要我這一代，因為我在綠島長大，我跟這些老一輩都有在聊天都很好，所以我知道怎麼把他們根深蒂固很傳統的那種概念，慢慢地轉，慢慢地轉啊，他也有看到我們在做觀光，在我的小孩，我的孫子也在做觀光，那我們也不能太過的說去做捕撈的動作。他們的概念有時候比我們好。']
# 方法剛剛有講了慢慢年輕人輔導來抓迴游性魚類很棒這很厲害慢慢很快很快衝擊度很大久時間久而久之年紀會變大體力會變差一口氣是漁獵動作體力會負荷打個條試了回來賣錢賣錢概念爸現概念運動70歲了下海馬生病70歲一代綠島長老一輩聊天根深蒂固傳統那種概念慢慢地轉慢慢地轉觀光小孩孫子觀光太過捕撈動作概念
# ['綠島，我覺得綠島真的要變成一個國際的小島潛水，不管是觀光或什麼的，那最第2個是我們這裡有一個很特別的漁業文化，也可以讓世界的人看到。 這個才能……，我一直在講說，把觀光跟漁民、魚法甚麼魚夜市結合在一起，這個是我想看的。不會像現在這樣，很亂。像現在大家就只能顧自己，把自己顧好，顧不了其他。']
# 綠島我覺綠島國際小島潛水觀光特別漁業文化世界講說觀光漁民魚法甚麼魚夜市結合在一起想很亂像現只能顧顧好顧
# ['助力。', '助力很多。', '助力只要政府真的好好地花個幾年的時間好好關心我們，我們漁會應該都可以做到。好好好花的時間，然後重視一下這個小地方。大概就OK了。']
# 助力助力助力政府好好地花個幾年時間好好關心漁會好好好花時間然後重視地方OK了
# ['他們其實東管處跟其實，這就我所謂的政府運作其中一個問題，多頭馬車，多頭馬車。 你像之前我們有在爭取說收清潔費遊客進來收清潔費，一個人跑幾10塊錢。那就是因為有綠島的東管處，你的鄉公所又要分臺東縣政府喬來喬去。 分不清誰要分比較多？ 誰要分比較少？ 就是會有這種牽牽扯扯的問題，所以始終沒辦法執行啊，所以這叫多頭馬車。東管處到後面，到現在在綠島，大部分都已蓋蓋涼亭、蓋廁所大概都這樣。啊，這這現在這個主任是我們有在跟他溝通，他對一些水下的東西啊，就是我們的標示物，像我們現在船多，要去潛水要幹嘛有職權，所以水域遊憩規範又沒有達到，所以才會有蟲有危險產生，現在是跟他在溝通做一些固定錨繩給自潛用的、給潛水船用的、給什麼用的，這個可能慢慢要去做起來。 啊，總有一天會有人被船輾過去的。', '沒有啊，因為這個纜繩以前都我們業者自己下去綁，自己下去固定。所以其實像我講的你，如果公部門政府單位他跳出來協助，很快，這些都是很簡單的事情，不是我們一直去找你們要逃啊，要跟你們要點經費來幫忙啊。自己每個月出多少錢，然後自己買繩子買出錢，真的斷掉，也要自己去修。']
# 實東管處這就政府運作多頭馬車多頭馬車收清潔費遊客收清潔費跑幾10塊錢綠島東管處鄉公所分臺東縣政府喬來喬去分不清分比分比少會有牽牽扯扯始終沒辦法執行這叫多頭馬車東管處到後面到現綠島大部分已蓋蓋涼亭蓋廁所這這現主任溝通水下標示物船潛水要幹職權水域遊憩規範沒達才有蟲危險溝通固定錨繩給自潛用給潛水船用給什麼慢慢做起總有有人船輾過纜繩業者綁固定我講公部門政府單位跳出協助很快簡單找逃要點經費來幫忙月出錢然買繩子買出錢斷掉修
# ['其實有了，我覺得你像中研院以前在綠島，可能風評都不好，是因為早期在綠島，你們在做什麼，沒有人知道，然後你們在水裡在做研究，在做商品在商品上面打了一大堆釘子什麼的。沒有人知道，所以你們會被公幹會被幹嘛。可是，如果你們把我們現在在做什麼會去弄到珊瑚礁弄到什麼，那大家會知道，那就可以體諒，我覺得這個是你們資訊透明化跟在地要有一點互動的原因，那我覺得現在新的概念開始很簡單，新的概念開始就是他有什麼能配合，像我剛剛講到的人工魚礁部分，因為你們也是直接就可以對到中央的單位吧，但其實可以像我們這樣，我們需要多一點，然後人工魚礁增加潛水的點。這有兩個好處是一個是可以增加魚群。他可以去聚魚，然後魚有地方躲，這是其中一個。第二個是不會綠島，現在就這幾個點，每天潛水員像下去，水餃 一樣，他還是會產生一定的破壞嘛，那我們把這些人也可以攤開掉這麼多個地方可以把他們分攤，不會造成那種環境的壓力這麼大。這就這兩個點，其實我覺得這兩個點你丟出去，給真的在研究懂這個的人他們就懂了，為什麼有的地方他們要做流量管制。 那也可以用這個地方來促成這個事情，我覺得可以跟你們合作，我們漁會跟你們合作都沒有關係，這我都樂觀其成。 如果你只說現在我們要辛苦是，我只能靠我漁會自己的力量去外面橫衝直撞，去講去說去做。那如果你可以把這聲音帶回去，那真的覺得評估可行性是高的，對環境是好，那為什麼不必一起來做？ 一起來爭取，一起來做。這可以啊，這個我很樂意。而且綠島所有業者漁民都會感謝你。因為還有一個人在背後擋批評。對啊，我是代表綠島所有漁民，我在背後幫你們擋批評，只要做好水調底下，沒有珊瑚礁就好。這個很好做了，順便把軍艦什麼可以讓他過來放成熟，這都可以。']
# 了我覺中研院綠島風評不好早期綠島沒有人然後你們水裡研究商品商品了一大堆釘子沒有人公幹會幹弄珊瑚礁弄體諒我覺資訊透明化地要一點互動原因覺得現新概念簡單新概念配合剛剛講到人工魚礁中央單位多一點然人工魚礁增加潛水的點這有兩個處增加魚群聚魚然後魚地方躲這是綠島這幾個點潛水員水餃會產生破壞攤開掉多個地方分攤那種環境壓力這就這兩個點這兩個點丟研究懂懂了地方流量管制地方促成我覺合作漁會合作沒係這我樂觀其成只說現辛苦只能靠我漁會力量外面橫衝直撞講去這聲音帶回去評估可行性高環境那為很樂意綠島業者漁民感謝背後擋批評代表綠島漁民背後幫擋批評做好水調底下珊瑚礁了順便軍艦放成熟這都
# ['很多，這這個太多了這個。', '你像文化的傳承，其實綠島文化很多，但是做不出來傳承我也搞不懂為什麼。像我爸如果。']
# 這這個太多了文化傳承綠島文化傳承搞不懂爸
# ['像我把一根吊著跟老漁民的漁法這些事情做起來，這個就很棒的文化，對，因為我們綠島就以前就海島就是靠這個生活的。那再來還有綠島一些，其實綠島很多。你們講名產嗎？我跟你講在地的美食啦等等，這些東西也是文化的一部分。我早期做啥、吃什麼、用什麼、做什麼再吃。']
# 一根吊著老漁民漁法做起很棒文化綠島海島生活綠島綠島講名產講在美食文化一部分早期吃用什麼做什麼吃
# ['這個要這個要問鄉長，因為我管的是漁會我也很想知道。', '我也想為什麼。', '這個是文化的部分。']
# 問鄉長我管漁會想想文化
# ['評分的標準是甚麼。', '就我自己的概念就對了。', '第一張，就那個綠島燈塔。', '這個也是綠島文化的一部分，然後這個地方是真的。我不知道，這個地方就是……如果我身為一個綠島人，我從小到大就有感受的就是這個地方，感覺啦。', '這個夕陽，這個就感覺是那種遊客。', '以前，我爸爸什麼都還沒有的時候，就是那個第一張。 那有第2張是因為這個地方很漂亮，後來很多的遊客來了才會有一個夕陽，在這邊看夕陽。']
# 評分標準概念了第一張綠島燈塔綠島文化一部分然地方地方我身綠島小到感受地方感覺夕陽感覺那種遊客爸爸還沒有第一張那有張是地方很漂亮遊客了才夕陽看夕陽
# ['燈塔。那個燈為綠島照亮了一下未來，所以……', '這個我挑這一張。', '這個地方雖然不是……他是因為那個。20幾個20幾年民國總統套房，那時候做。所以他還是從那時候到現在，他還是都把持著原始很完美很美的狀態，所以我很喜歡。這個地方，它是房子，圍牆啊，全部都是用我咾咕石做的，都還是保持那個風貌都沒什麼很大的建設跟改變，我覺得這個就是綠島最美的地方 。', '朝日溫泉，政府把它標出去一次十幾年，亂七八糟的，沒辦法收回來，一大堆問題。以前，我們就那個四海溝，自己在那邊跑，現在把它做起來，沒有比較好。有點破壞掉，然後後來接手他們招標，那麼長的時間接手的集團什麼的，他們也沒有好好管理好好做。']
# 燈塔燈為綠島照亮了未來挑這一張地方20幾個20幾年民國總統套房那時候把持原始完美美的狀態喜歡地方它房子圍牆全部都是咾咕石風貌沒什麼很大建設改變我覺綠島最美地方朝日溫泉政府它標十幾年亂七八糟沒辦法收回一大堆四海溝跑它做起破壞掉然後後來接手招標長時間接手集團沒好好管理好好
# ['小長城第2名。', '綠島最東邊的圖卡。', '還是日出出來，應該是看的到。這個地方也看到希望。', '都不會。', '其實這些監獄啦、政治犯啊，什麼這些不是我們以前，綠島人要的東西。 那是臺灣你們臺灣就是……', '放過來的，那才在這裡造成一個根深蒂固的文化，在這裡，這不是我們在地的。那我們一直長期以來被這個文化，大家就覺得綠島就是監獄犯人監獄犯人監獄犯人，那我們還能有什麼其他可以凸出來的地方？那你向文化部他們很有錢，他們政府每年撥這麼多的錢給他們做這些政治犯回來啊，音樂會啦什麼的。他們都有這些相關的經費啊，活動阿什麼的。可是我們其他的沒有哎，綠島被這樣蹂躪了那麼久也沒有特別的東西啊，這種概念。', '很好很好，真的很好，可是這個不是我們……', '在地的文化，這真的都是外來的。', '那外來的已經引導我們的文化那麼久了，就是在這裡的，我們所謂的文化的這一塊這麼長的時間了，是時候呢，大家做一點調整改變。我們上次跟他們開會，教授陳培棕陳教授也去了，我也有講這些。其實他們不管這裡乘船、這裡的在地的一些東西，你們的腹地這麼大，你們經費那麼多，可以做一個屬於我們的博物館、故事館什麼都好。記錄我以前用什麼東西耕田，因為以前用什麼東西耕田，這些可以把它做進去。 我們以前怎麼做柴魚，綠島柴魚以前是最厲害，現在都失傳。像這些，他們可以幫你們做進去啊，而且不是只有政治犯的部分。']
# 小長城名綠島最東邊圖卡日出地方希望監獄政治犯綠島人要臺灣你們臺灣放過那才根深蒂固文化長期以文化綠島監獄犯人監獄犯人監獄犯人還能凸出地方向文化部錢政府撥錢給政治犯回來音樂會相關經費活動阿什沒綠島蹂躪了久沒特別概念文化外來那外引導文化久了文化這一塊長時間了一點調整改變上次開會教授陳培棕陳教授了有講乘船腹地經費一個屬博物館故事館什麼記錄用什麼耕田用什麼耕田它柴魚綠島柴魚厲害失傳幫政治犯
# ['農地很多，但是農地都蓋著亂七八糟的。', '花生跟地瓜，以前還有重稻米。', '所以以前大戶人家才有米可以吃。', '比較沒錢的捕魚沒時間種田的，種田就是地瓜跟花生了。', '像我們家早期是抓魚的，隔壁是種田種菜，我們會送她魚他會送我們菜或米，交換也是用買賣的。這個感覺就很好，到現在我也會做這樣的事。 我抓什麼魚我會分一點給你左右鄰居，那些阿公阿伯什麼老一輩，他們現在沒辦法下海抓魚，他們種菜什麼他會分我 。所以有時候拿一把蔥給我，拿一個高麗菜給我拿一個什麼菜。所以我還是喜歡的是這樣的地方，這個才有人情味，這個才需要被傳承，你像臺灣可能嗎？你去拿一個東西別人吃，人家要懷疑你，你有什麼企圖？ 在這裡不會，我有魚我就分給人家啦，他們有多餘的菜什麼，他們也會分給我。這個對的阿，那個感覺才是對的。不好意思，我先。', '先處理一下。還會很久嗎？']
# 農地農地蓋著亂七八糟花生地瓜重稻米大戶才米吃沒錢捕魚沒時間種田種田地瓜花生了家早期抓魚隔壁種田種菜送魚他送菜米交換買賣感覺到現事抓什麼魚我會分一點給鄰居阿公阿伯老一輩沒辦法下海抓魚種菜他會分一把蔥給高麗菜給菜喜歡地方才人情味才傳承臺灣東西別吃懷疑有魚分給餘菜分給感覺才不好意思我先先處理還會久
# ['善良，真的叫太善良了，善良到變笨。', '這邊的人很少跟老一輩很少跟外面接觸，所以我們的生活環境就是這樣，你說像老一輩，包括我爸也是你說像活到現在70歲了，你要帶她去臺灣走走嗎？ 他們還不一定會想要去。 但是他每天的例行公事，一定要下到海。泡一下水， 這個是真的。那遇到很多大小事，他們不懂得反省，也不懂得該怎麼辦就承受，一直承受，老一輩就一直承受到現在。 可能這些頭人，他們有各自的想法，各自的利益，那他們就跟著這些島民講一講。我有力出力了就知道很簡單，然後就就結束了，以前就是都用這個方式。 所以到我這一代就是，我的概念就是該做什麼就要做，什麼是對的就要去做，就是要改變。']
# 善良太善良了善良變笨老一輩外面接觸生活環境老一輩包括我爸活到70歲了帶臺灣走走還不想要例行公事海泡水大小事懂得反省懂得辦承受承受老一輩承受到現頭人想法利益島民講一講出力了簡單然後就結束了方式一代概念改變
# []
# ['收你的嗎？', '我備著不是我都是去因為我譬如我要interview他講英文，我就聽不懂，不是有時候就很多專有名詞，因為重複的聽，因為我的書都是從國外的，所以我常常就要，而他要interview他，他給我一些意見。有時候如果乍聽，有時候我們不一定有不懂。']
# 收我備我要interview他講英文聽懂專有名詞重複聽書國外interview他給意見乍聽懂
# ['所以我就經常我好幾臺，而且用掉好幾臺。', '好，那沒問題。']
# 幾臺掉幾臺沒
# ['本來很少了接觸，我就很少接受。因為我自己寫書不喜歡接受訪問，因為太多，我自己也很多安靜的時間，對因為寫書也常常思考架構，而且翻譯一篇文章要很久的時間這樣。，所以我就很少接受一些訪問什麼的。但就我喜歡跟基層接觸。', '2024年5月4號二零。', '我過到，2023對。', '這個給我好了，因為有點好這樣子。', '我們今天你來的正是時候，剛好沒什麼生意。今天禮拜三禮拜四生意比較清淡。', '六日一，不是五六日。', '因為你就一般來講3天嘛，3天然後就是禮拜一早上在泡完再回去這樣，所以碼頭富岡漁港的碼頭是禮拜二餐廳都休假。', '那就對了，而且富岡漁港那邊的都那個餐廳都是這樣，就大家都不在。', '對一整排喔禮拜二都休假哦，真的就是這樣。', '我也是後來觀察才知道。(正式訪談開始)', '我是2021年9月份，9月份就是過來的，然後到現在這樣多久了？ 一年半吧，現在是4月嘛，再加上……，一年半。', '我因緣際會的，因為這個本來這個是ROT朝日溫泉吶，原來的這個主人是東方之泉。那它其實那段因為疫情這段時間哦，就是說沒有生意嘛，再加上這個原來東方之泉的老闆，他被停權，被停權幾乎就是結束了，被停權以後，我弟弟就經由，就好像有人介紹就是說來協助。那他是跟原來老闆是朋友，那協助以後就是因為他現在破產了，破產以後，那我弟弟就出面，因為我弟弟是臺商嘛，就是出面，然後協助他。其實就是有關債務方面的處理，然後接著下來就是因為被停權是有很多因素的，很複雜的因素，比如說你這個修繕的問題，安全的問題人員財務的問題呀，人員管理的問題種種，這個綜合起來他才會被停權的，那所以我們那我弟弟就請我幫忙，那我其實就過來這樣看，那其實因為我自己是臺東人，那也來過綠島度蜜月的時候來綠島。以前我唯一拍一張照片，就看到那個林投樹而已，你知道嗎？', '林投樹在哪裡都不記得。就對我來講就是，進來了以後我就想說，我來回想我當時想的綠島跟現在的綠島就完全都是不是一樣，那我就覺得我就進來了這樣子。那時候是9月份，天氣很好，我覺得四處就是像現在這樣春秋在某一些。 時候他的那個氛圍是一樣的，像現在熱也不是太熱，對然後風也沒有颱風的話就很好。那我覺得就是整個很漂亮，就是我覺得漂亮的風景。每天同樣是工作，那這種漂亮，你看海洋陸地天空，然後整個的感覺。每天在這種地方工作，其實是會對生命有積極的意義啦，我覺得會滋養我們的心靈，所以我覺得就是說，因為我已經都是，在過去在媒體工作實在很操，日以繼夜的操，同樣是操我們都在燈光下在電腦前面，我覺得這裡同樣是操。在這個碧海藍天這樣，所以我覺得我就留下來了，因為我弟請我暫時幫忙，後來因為留下來，我們那時候我在臺北，我們是觀光旅遊業，剛好也都是疫情，完全都是停擺。 所以我們，我們公司原來有20,30個人，所以我就是協助他們就是來這個地方，所以我們現在有一組人是從臺北過來的，我們就把臺北那個經營的方式帶過來，所以從那個時候我們就跟我弟一樣，就是協助他去整個把所有總的這個問題慢慢一件一件，按照東管處的協助之下，他也覺得說我們來做的話，慢慢的就是一件一件，這樣做下來，我覺得他也慢慢的就是我們慢慢獲得信任吧，還有在當時因為有一些跟業者，所以業者因為他們有販賣我們朝日溫泉的票，那那當時你看停權事情就很大，他手上有票，他已經付錢了他預售的，那怎麼去處理？所以這件事情我們就從就是回收這些票，然後我們給它的票是透過銀行履約保證的，這個就好像Seven，你拿到那個禮券，你視同現金一樣，因為那是就算Seven不換你去銀行，一樣可以把錢現金換回來，這就是我們慢慢就是用就比較，一步一腳印比較踏實的。', '然後除了就是去把業者這部分的，這個財務、票務還有公共關係，因為他對我們也很不信任了，所以我們也要顧慮到這種綠島那麼小嘛，就是我們就是要敦親睦鄰。這樣的工作那以及我們同時要展開的是個各項的安全修繕，其實所謂的安全問題就是修繕，你就是讓大家進來有一個安全的環境，其實他很老舊嘛，很老舊其實沒關係，可是他就是要不停的修繕，而且這裡是海風，每天這樣吹的話，它其實就是要不斷的，他很容易壞，你看我們沒有電子的東西，我們電子的東西很有時候就是半年，就像我們在那時候就是大家不是要量那個額溫嗎？我們用電子的話。', '很快，很快哦，他就是壞掉了電子的東西，他很快就壞掉，3個月2個月就壞掉，那甚至於像冰箱啦。這些外面飲水機都很容易壞，所以就是要一直要維護，然後一直要，隨便說擦油漆，擦油漆就是這樣，從頭擦到尾，你後又開始擦了。然後鏽掉的很多，然後崩掉的，然後尤其是9月進來，馬上那時候就開始進入修繕哦，那進度也是很慢，因為一下子風一下子雨的，你們如果要來綠島也常常停船嘛，或者飛機也不飛。這種狀況很普遍，我們一樣，這種天氣他們就不修。然後綠島的我們這些工人又很難請。譬如說我們機器壞了對不對？我們的機器在海邊，從那個因為我們是從地下，我們的溫泉從地下抽上來，好那現在假設它壞了，那我們有一直在那邊，那要等他退潮。等他退潮的時候，我們要救生員，我們要4個救生員在旁邊。因為下海嘛救生員，然後還要扛，還要有電工，還有設備馬達要買好，還有工人扛下去。 好了那我們這樣協調有時候好幾天。救生員可以了，電工沒空；電工可以了，救生員說，哎，那個時間他不行。救生員也可以的時間又漲潮也不行，就很多這種。他其實是要很大量的協調，還有就是要天時地利人和才下去。', '他有時候一等，所以有時候我們馬達壞了，如果影響到。那個就是放水，去泡湯的話，有時候我們會停，我們就必須真正就必須那一天就要休園。所以我們去年就經常就是說，因修繕，然後修園修繕修園，這種狀況就蠻多的，所以我們就是這樣一年下來，再加上銀行履約票的那種申請，因為兆豐銀行也是非常非常的靈活，你知道然後我們就是，總是這樣做綠島人，他們泡湯，他看到我們這樣做，那履約票券，因為我是跟他的利益有關，我們就是做的比較紮實一點，那我盡量地每天去敦親睦鄰，比如說我們這裡要採購，我就盡量透過這裡的，譬如說我們這裡，像我都賣這裡的農產品，像我賣這裡的香蕉，賣這裡的我其實大量的從臺東運進來，也是更便宜。蔬菜，像這裡我賣的，有時候就是這裡的土產，我都賣土產的話新鮮的新鮮的我都在這裡收購，那收購就跟他們有接觸。後來是說，這一個我們要賣那個蛋，我們不是自己去，因為我們大量的有溫泉蛋，要每天熱賣嗨，這是我們就是如果叫臺東，因為他們也是都透過臺東引進。', '那我就透過這裡的，我全部我不自己賣，我們就儘量透過這裡，其實透過這裡，你就有跟他接觸的機會。 然後呢這樣子我們就慢慢就邀請他們說，哎現在不一樣了，有空來泡湯，我每次我的再見語，就是要來泡湯這樣，他們就溫爪(台語)。 慢慢現在，大家我騎在路上，我摩托車騎在路上，他們也就認識了，然後這中間我就想說要活化，所以我就在這邊辦一些活動，以及就是因為這裡，我看他們都在撿海廢那個垃圾哎就是，在一個機會之下，那時候島嶼見學', '那個，那個就是你上次跟那個誰來你上次跟。', '跟一個男人，小佑還是小玉。Speaker1:', '男生，小玉啦小玉。', '就我們也是想要那時候想說那個牆，他剛好說要再找牆，我說我剛好要找藝術家來這裡。那我們就是好，就是很快的，我就跟藝術家有接觸上這樣子，然後我們就是就做了，這個就是我們就是把海廢再生，這件事情提升，因為只是撿的話，只是乾淨的問題。你如果說利用它再生後的藝術化，變成一個教育場所，或者是像現在東管處18號有回塑再生的活動，他們事情一個老外藝術家在旅服中心做，那他們就是接東管處的案子。那他其實做海廢再生，他是做商品，他把這些回收的那些像這種寶特瓶，或者是那個比較薄的，他分類還有比較大的，他就把幾個分類還有分顏色，之後他把它打碎以後他把它做成商品，譬如說像這種這個，你們也可以其實去海廢再生，這個就是從那裏做來的，他有各種膜。', '朝日旅遊中心。', '他做各式各樣的，那他也做成大的，也做成桌板，桌板有沒有？這個如果做桌板他的膜，那他也有做成椅子，那這個就是商品化的東西，那我是不曉得他們還可以做到什麼程度了，那這裡面就要他要去配色，對不對？ 它還有一個美感的問題是就是整個設計的問題，那他就用這些回收回收的這些，這些海廢它做成的。那我是把它做成一個教育牆，那也是綠島第一座，那就是去年，我覺得我們去年在整個這個就是在維修，還有把過去傷害的關係修復以後我就開始做，今年開始我就譬如說像這兩根柱子，我就認為他設計就是一個印度教的東西。印度教的東西，因為我覺得這個應該是濕婆神的象徵，你如果去過吳哥窟你就曉得，所以他基本上當時設計它的人，這整個進來這個地方應該是一個神殿，你去過吳哥窟嗎？', '他有機會去的話，他這個就是其實他這個就是，印度教的這2個東西在吳哥窟樣子太像了，所以巴厘島也是這樣印度教的東西，所以我就請那個印度就是舞者來這裡跳舞，就是營朝日還有送夕陽這樣子，就是因為這裏是可以迎接2023年的第一道署光，那印度教的話，其實它的整個就是說那個天啟，就是跟宇宙初始的時候是就是他被他們在就是須彌山，他們神都住在須彌山聳立在大地的中央嘛，那所以那這底下它外面有護城河。護城河後面，這個就是海洋包圍的這個那跨越護城河的虹橋，便是通往天界的大道，所以這裡是天界，是這個意涵。那這些東西我講了，然後就是希望，有一個開始把一些，這個就是說觀光的感覺的那一種氛圍帶出來，所以我們就是連續在跨年，我們講的就是新曆嘛。元旦之後，接著像農曆年農曆年，我也請舞者在這裏跳舞。然後，所以他有從印度來的，他從頭看到尾還追進來，這樣子就覺得哇，非常的神奇這樣，因為他看的懂了，他看懂了，那另外我們就是海廢藝術牆，這個東西就是現在那座牆，我們把那個就是那個結合藝術家，他要把撿來的垃圾就是 ...
# 本來了接觸接受寫書喜歡接受訪問太多安靜時間寫書思考架構翻譯一篇文章久時間接受訪問喜歡基層接觸2024年月號二零我過2023這個給了這樣子沒什麼生意禮拜三禮拜四生意清淡六日五六日天嘛天然禮拜早上泡完回去碼頭富岡漁港碼頭禮拜二餐廳休假了富岡漁港餐廳整排喔禮拜二休假觀察才正式訪談2021年月份月份然後到多久了一年半月一年半因緣際會本來ROT朝日溫泉吶主人東方之泉它那段疫情這段時間沒生意東方之泉老闆停權停權結束了停權弟弟經由好像有人介紹協助老闆朋友那協助他現破產了破產以弟弟出面弟弟臺商嘛出面然後協助債務然後接著下停權因素複雜的因素修繕人員財務人員管理種種綜合才停權弟弟請幫忙那其實臺東人過綠島度蜜月綠島唯一拍一張照片林投樹林投樹記得了想我來回想想綠島跟現綠島了這樣子那時候月份天氣我覺四處像現春秋氛圍現在熱太熱對然後風沒颱風話很漂亮我覺漂亮風景工作漂亮海洋陸地天空然後整感覺地方工作生命意義啦我覺會滋養心靈我覺媒體工作實在操日以繼夜操操燈光電腦我覺操碧海藍天我覺留下了我弟請暫時幫忙留下臺北觀光旅遊業疫情停擺公司2030協助地方組人臺北過臺北經營方式帶過我弟協助總慢慢一件一件東管處協助之下話慢慢一件一件我覺慢慢慢慢信任跟業者業者販賣朝日溫泉票停權很大手上票經付錢了預售回收票然後我們給它票透過銀行履約保證好像Seven拿到禮券你視同現金一樣Seven不換銀行錢現金換回來慢慢一步一腳印比較踏實然業者財務票務公共關係信任了顧慮綠島要敦親睦鄰工作展開各項修繕修繕環境老舊老舊沒關係不停修繕海風吹話它壞電子電子半年要量額溫電子話很快很快壞掉了電子很快壞掉月月壞掉冰箱外面飲水機壞要維護然隨便擦油漆擦油漆擦尾擦了然鏽掉然崩掉然月馬修繕進度很慢一下子風一下子雨要來綠島停船飛機不飛狀況天氣不修然後綠島工人難請機器壞了機器海邊地下溫泉地下抽上那現假設它壞了那要退潮退潮救生員救生員旁邊下海救生員然後還扛電工設備馬達買工人扛下去了協調幾天救生員了電工沒空電工了救生員時間不行救生員時間漲潮不行協調天時地利人和才一等馬達壞了影響放水泡湯話停休園去年因修繕然後修園修繕修園狀況蠻一年銀行履約票那種申請兆豐銀行靈活然後我們綠島泡湯那履約票券利益紮實一點盡量敦親睦鄰採購盡量透過賣農產品賣香蕉賣臺東運更便宜蔬菜賣土產賣土產話新鮮新鮮收購那收購接觸這一個賣蛋溫泉蛋熱賣嗨這是臺東透過臺東引進透過賣量透裡透過接觸機會然後呢這樣子慢慢邀請哎現了有空泡湯每次見語要來泡湯溫爪台語慢慢騎路上摩托車騎路上了然這中間想活化辦活動撿海廢垃圾機會之下那時候島嶼見學上次上次男人小佑小玉Speaker1男生小玉小玉想要那時候想牆他剛找牆找藝術家來很快藝術家接觸這樣子然後我們了海廢再生提升撿話乾淨利用它再生藝術化教育場所東管處18號有回塑再生活動老外藝術家旅服中心接東管處案子海廢再生商品回收寶特瓶薄分類幾個分類分顏色之後他它打碎以後他它做成商品海廢再生裏膜朝日旅遊中心各樣做成做成桌板桌板沒桌板膜做成椅子商品化不曉得他們還程度了這裡面配色它美感設計回收回收海廢它做成它做成教育牆綠島第一座去年我覺去年維修傷害的關係修復這兩根柱子設計印度教印度教濕婆神象徵去過吳哥窟就曉得設計它這整地方神殿去過吳哥窟機會話印度教吳哥窟樣子太了巴厘島也印度教請印度舞者跳舞營朝日送夕陽這樣子裏迎接2023年第一道署光印度教話它天啟宇宙初始須彌山神住須彌山聳立大地中央底下它外面有護城河護城河後面海洋包圍跨越護城河虹橋便是通往天界大道天界意涵我講了然希望觀光感覺一種氛圍帶連續跨年講的新曆元旦農曆年農曆年請舞者裏跳舞然印度尾還追這樣子神奇懂了懂了海廢藝術牆那座牆藝術家撿垃圾洗一洗它藝術牆藝術牆發現地方停車一個網美的地方他現那面牆自然服很快接受車子停停然後呢那個場它表演秋分日出照射到那面牆埃及阿布辛貝神殿秋分第一道屬光照到照到冥神暗摸摸台語晚上它一年四季神陽光不會照神殿秋分春分那天第一道署光照到時間跑我現先塑造那樣子我現在講人來講還有點距離我現那道牆布局希望那道牆廣場綠島學生八股以後再旺請表演這是表演然後我們請話有感覺工作長期工程員工話加總話30並全部都是編制編制話編制話綠島比例一年剛來那綠島工作員工基層基層勞力擦油漆水電洗池子賣票我覺朝日溫泉議題我覺找特別文化活動它想辦法這一間餐廳它倉庫那員工用餐它花到錢情況之下它定了矮書架青木靈來幫定做工朋友天天外面做工幫訂書架開心開心開幕請訂書架我現咖啡書屋然後我藏書因為現從然辦公室這個現讀不到先最新好像聯合文學朋友出放一塊然後把家裡收藏通通搬到了請藝術家來畫幾幅畫做成明信片畫都故事然後那攝影然後我們打卡送明信片類似那請綠島現導覽請導覽那座橋那座橋經常來教室活動臺東縣衛生局辦活動撿垃圾舉辦講座這樣子一年活動一年辦撿撿垃圾然一堂講座沒了那其實它延伸經營理念話這一個海廢再生藝術層次企業角度話透過它拉高一點拉高一點話企業形象第一座牆示範性作用才開月號請綠島監獄幫撿垃圾請典獄長揭幕了沒它議題很樸實方式幫撿垃圾連典獄長了那面牆做好了垃圾垃圾變黃金了藝術牆教育牆表演場所敦親睦鄰敦親睦鄰觀光客來講話整體政府他現生態的島不足以去過去過100多個國家我覺去過海島船以那種島嶼一種氛圍沒它純樸漁村那事實上它漁村概念漁港太太期待那事實上經放棄了農業放棄了工業工業沒沒了話跑外面了外面臺東話有種花生種稻稻花生還有種玉米自然資源上林投果雞角刺那株雞角刺春天滿地白色開白色臺灣是開黃色請喝雞角刺花我現它做成我現賣GMP話做法它冰起雞角刺薺科它臺灣人蔘綽號臺灣人蔘它園區好多露營區你聞沒蔘去年放在賣不記成本賣現賣80塊去年賣60塊收賣貴了有人採它我心裡想收採了收嘛台語2612了話會給有人以後家裡檸檬太多本來這邊種山邊業餘事實上工作事觀光觀光潛水店吃反正民宿沒系統發展那像它做起怕GMP喝了拉肚子辦賣林投林投果汁想跑研究了想試賣了我覺這段時間希望發展地方文化
# ...
# 綠島只會越來越開發並不覺停短暫一陣子回來只只會開放並不覺停滯這因還會有人開墾然後再蓋綠島地方還蠻奇特了地方有電然後呢就會種火龍果山上地方地方火龍果你會莫名其妙地方種什麼火龍果火龍果因它生長的關係會用電燈照射快速成長這時候農地申請電有電了事請水變更它本來農地然後變成建地之後去記得變更它流程變更變更它變更需求農地變建地會流程必備條件只地方地方間便挖掉開始種火龍果間開始長出葉子之後再過一陣子房子生出了大部分農地話建地那當然沒了沒找地方先變成火龍果要蓋房子房子跑有空話騎車過山古道騎路上地方開始長火龍過陣子會長房子花錢買吃火龍果外面運進了建地對來講農地做事想賺錢話過山古道種火龍果吃火龍果先爬山摘然後再回來我覺想想講太多殺超怕殺掉了才地方地方喔先長火龍果然後就會長會長燈會長房子然後在地方喔這是老師老師長香蕉那一塊間發現剷平了然間長了一堆香蕉然後之後他房子話間停車場停車場很小那種一格幹第一件先省地價稅然再過一陣子發現它房子這中間過渡期還看還不確定先它停車場停車場完了想到他後續然後他房子臺灣也我覺機會話研究停車場會長房子臺灣是
# ['好難喔。', '可是我真心覺得好難。就像我剛剛說的，已經都你說了想像未來的畫面是什麼，我未來的畫面就是開發，然後很多房子房子，那你要他多好？', '我想不出來，沒有美好的。', '不要再開墾了。', '不要再開墾，然後大家為了賺錢，我真的能理解，但不要再開墾了，我覺得再開下去就真的沒有那麼漂亮，因為我連我的朋友去蘭嶼，他也都說蘭嶼沒有以前漂亮，可是因為我們沒有去過蘭嶼，我沒有去過蘭嶼，所以我不知道蘭嶼長怎樣但我那些朋友去蘭嶼，然後再回來的他們都說，他們以前去蘭嶼到現在這樣去蘭嶼，他們也是覺得蘭嶼變好多，然後也可能也就是都市再開發，你可能就是在也沒有那麼原始那麼漂亮，那你明明是想要他可以很想要這裡可以一直保持得那么好，所以才會有有人來玩嘛，但你卻一直開發一直開發到最後他不就跟都市沒什麼兩樣，他就只是大家來這邊，就只不過就是變成另外一個都市，只是這裡的附加價值就是有海，然後大家來玩水。所以要的話不要再開發了吧？你如果真的要他不要再那么美好的話不要開發。']
# 好難喔真心難剛剛了想像未來畫面未來畫面開發然房子房子想不出美好開墾了開墾然了賺錢理解開墾了我覺開漂亮我連朋友去蘭嶼說蘭嶼漂亮沒過蘭嶼沒過蘭嶼蘭嶼長朋友去蘭嶼然後再回來去蘭嶼去蘭嶼覺得蘭嶼變好多然後也都市開發沒原始漂亮明明想要想要那么才有人玩卻開發開發都市沒什麼兩樣只都市附加價值有海然玩水話開發了那么美好話開發
# ['但其實說真的，我剛開始其實我不太確定中研院是在幹嘛，我認真不知道中研院在幹嘛，他們他們只跟我說，那邊有個海洋研究的，那海洋研究我比較可以理解，因為畢竟我們這邊剛好就是都是海嘛，所以你可能要研究海洋的物種生態可能珊瑚什麼的，我覺得這個都還能理解，中研院的權利到哪？他可以做什麼？']
# 我剛太中研院幹我認真不知道中研院幹只有個海洋研究海洋研究理解海嘛研究海洋物種生態珊瑚我覺還能理解中研院權利到做什麼
# ['我因為我想先知道嘛，我想我想知道他能做什麼。', '就像你剛剛問我的，那些龜灣的房子蓋那樣，我能不能拆？', '所以我想知道中研院的權力到哪，那他能做什麼，我才能知道你……', '但我覺得說真的，以紙本上要去做推廣的這件事情不容易啊，就不容易。', '所以就需要很多錢啦，對呀。', '因為要推廣，要推廣就要錢，要辦活動就是要錢，經費取得容易嗎？', '經費可以做推廣。', '你必須計畫能做出來計劃，我可以才會才能做，跟我一樣，我們也是有錢可以做，只不過要提計畫，你要去怎麼要讓它們上面的人吐錢出來。', '給我錢。']
# 想先想想剛剛問龜灣房子蓋我能拆想中研院權力以紙本上推廣錢推廣推廣錢要辦活動錢經費經費推廣計畫做出來計劃才錢只不過提計畫吐錢給我錢
# ['代表綠島嗎？', '喜歡這一張，我覺得你要在我覺得火燒雲這個東西在本島不是那麼容易看見比較在離島比較常看，所以我覺得火燒雲這件事情比較能夠像是在離島吧，但你如果要說他代表的話，我覺得燈塔就還蠻能可以的，但講到綠島自己都會想到綠島有個燈塔，那你如果要真的要講到綠島的話，能夠代表我覺得應該是人權園區，白色恐怖紀念園區。', '心中第一，心中第一。第二名要能夠，如果要我能夠覺得他能夠代表綠島的話，代表綠島，可是說真的他因為我是在這邊待比較久，我知道他是哪裡，不然這樣子其實我會不知道他在哪裡？', '應該這，這是第二張。', '對，然後這是第三張。']
# 代表綠島喜歡這一張我覺火燒雲本島離島較常我覺火燒雲像是離島代表話我覺燈塔還蠻講到綠島想到綠島有個燈塔講到綠島話代表我覺人權園區白色恐怖紀念園區心中第一心中第一第二名代表綠島話代表綠島久這樣子我會這是張然這是第三張
# ['火燒島，我覺得綠島就是大家都講了，綠島就是叫以前的名字就叫火燒島，而且因為他剛好有火燒雲，所以我覺得它很適合叫這個名。']
# 火燒島我覺綠島講了綠島名字火燒島火燒雲我覺它適合名
# ['島上，他有燈塔這個東西，其他地方當然也有燈塔，但大家如果有講到綠島的話，一定的話想到燈塔這個東西，所以我就覺得能他能夠比較代表，但當然說他有比較完整的，可是因為就像我剛剛說的，要有火燒雲，離島比較常見所以我才會覺得說火燒雲這個東西是比較能夠使綠島的東西。']
# 島上燈塔地方燈塔講到綠島話話想到燈塔代表完整剛剛火燒雲離島較常見才火燒雲綠島
# ['有，我們是以景點來看的景點。景點說因為如果說你要就是來綠島，就是以我在那邊接電話的那個過程，或者是我朋友來詢問我的過程，他們會提到要去的行程景點都一定會包含他，一定會包含小長城。燈塔是大家都會去的嘛，然後大家一定都會去小長城下面走走，然後去看一看，然後去看一下那些趴趴狗、睡美人，然後再回來。但因為人權跟白色恐怖有關係，所以我都會說我都會跟朋友們說，你們都來綠島，我真的覺得你們要去看一下，你們如果沒有當時因為我們沒有辦法，我們沒有經歷過當時恐怖時期白色恐怖時期所發生的事情，但至少你要能知道他以前做什麼事情，然後以前的人究竟是生活在怎樣的環境裡面？受了多少冤屈或什麼的，我覺得大家都應該去看一看，所以我們現在能夠講話那么自由，你可以在這邊罵政府罵什麼有的沒有的，那是因為前面的人就是已經經歷過那些事情，然後到開放了民國76年解嚴開放了，然後到現在我才能才能夠那么的自由的去說你想說的東西，你才能夠那么的民主。那如果沒有前面的這些人，經歷過這些被壓迫的時期，就我們現在可能還在就是如果沒有當時的人受的這些苦，我們後面的人不會那麼的輕鬆。所以我覺得不管怎樣，都應該要來看過，就是你應該要知道。所以白色恐怖園區這件事情是大家都來看的，因為他就在旁邊嘛，我沒有選它的原因是因為不來的人真的不知道在哪，所以我才沒有選他，因為大家都知道這個地方就是在草坪外就是，所以我就覺得這點很重要。', '不喜歡嗎？不喜歡我才不喜歡。', '我就只能挑沒看過的地方，因為大家都知道來綠島要搭飛機嘛，然後燈塔燈塔，朝日溫泉啊，這個真的是你沒有仔細看你真的不知道他是哪裡所以我只能我只能用這種方式，最後一名給他。因為不喜歡他，只是因為你如果真的沒有來過，然後沒有看過那麼多介紹的話，你會真的不知道這裡是那裏。', '不知道在哪，對真的不知道要不就真的。當然以我們來了，我知道說他就在那個紀念館的外面了，所以我們我們看到都知道，可是如果說你是沒有來過的，你要他挑我覺得他不出來。']
# 以景點景點景點綠島接電話過程朋友詢問過程提到行程景點包含包含小長城燈塔然小長城下面走走然後去看一看然後去趴趴狗睡美人然後再回來人權白色恐怖係朋友綠島辦法沒有經歷過恐怖時期白色恐怖時期發生至少做什麼然生活環境受了冤屈我覺看一看講話那么自由罵政府罵沒已經經歷過然後到開放了民國76年解嚴開放了然後到夠那么自由想夠那么民主經歷過壓迫時期還在受苦面輕鬆我覺看過白色恐怖園區旁邊沒選它原因不來才沒選地方草坪外不喜歡不喜歡才喜歡只能挑沒看過地方綠島搭飛機然後燈塔燈塔朝日溫泉沒仔細只能只能方式一名給他喜歡來過然後沒有看過多介紹話裏了紀念館外面了沒來過挑
# ['我覺得他是一個熱情奔放的島嶼，我的確覺得他非常熱情奔放，因為你看我們我覺得他們也都還蠻能夠接受許多外來的人。', '這時候這個問題要想一下，你到底遇到了是怎樣的綠島人？我遇到大部分的綠島人都很和善。', '當然也很熱情啊，就是你如果有一些可能需要尋求幫助你的人，或者是你有可能有一些一直想要請他們幫忙，或者是你在這邊有些事想做做不了，那他們可能可以幫你引薦，因為他們是綠島人，對我覺得他們也都還蠻熱心的，當然那當然很不好的，當然也是有啊。', '很怕講完的時候我會被抓去殺掉這樣子。']
# 我覺熱情奔放島嶼確覺熱情奔放還蠻接受許多外這時候想了綠島大部分綠島和善熱情尋求想要請幫忙事想做不了幫引薦綠島還蠻熱心不好很怕講完我會抓殺掉這樣子
# ['哦，沒有，我就是從小是在綠島土生土長長大的，後來就學完回來，就是因為我本身是公費生，就回到綠島衛生所服務這樣子，對在這邊已經快30年了，就是回來工作的。', '長大，我因為我國中之後，我就到外到屏東去唸書，然後之後我學成之後再回綠島服務。這樣子，所以這個衛生所其實是從我們舊棟，然後有這個有新建的地，大的就是我見過這個大樓是從107才落成的，這樣子。', '那在醫療的部分，其實是這幾年其實，我們局跟政府的就是對偏鄉其實是都蠻重視的，所以就是說我們這個方面的醫療還有一些設備上意思部分的還有馬偕的協助，這是在綠島能夠提供不足的一些醫療的地方盡量都去補足這樣子，那就像我們之前後來109之後開始，都有一些遠距醫療的，就是因為平常你沒有皮膚科，那些的科別還有那個眼科那一塊的，跟其實還有一個心臟的部分這樣子，皮膚科、耳鼻喉科這些都有納進跟眼科，其實這個當中其實是呃，應該說變成是不同補足不同的科別，平常這樣子就是變成有多的科別的意思出來。那民眾或者是遊客進來的部分。', '就像潛水或是什麼耳鼻喉科，其實是因為那個潛水耳朵的一些，所以其實這一塊在夏天是蠻需要的這一塊；那皮膚也有因為有時候被海上的東西或是什麼去的話都有；那眼科的話，因為我們也都有都有採購一些新的儀器眼底鏡什麼那些其實大部分其實都可以做這個部分的及時的處理，真的是沒辦法部分的話，可能就是會轉診到臺灣過去這樣子對那醫療部分用加上我們一些緊急後送的相關的SOP就是空中轉診，這一塊的部分，還有海巡這一塊的，其實綠島的醫療其實是慢慢的都在一直在進步的這樣子。那當然這是在居民的部分，其實我們這樣講，是之前是比較農業時代跟漁業時代的，可是在後面這幾10年之後，觀光地進入，其實綠島鄉變成是觀光事業，那當然在綠島的人口的模式上會有所改變，是比如說像本地的老人家，有時候是年輕或生病的，基本上因為他們覺得說，有時候可能在臺灣會比較方便，那小孩子現在這邊都是年輕在做生意的，他有時沒辦法照顧，那有的就是說真的，除非是說，很生病了，必須有一些特殊、沒有辦法照顧的，他們有時候都會送到臺東的安養機構去，那有的就是舉家遷出臺東就到臺東去了。對，這邊他們有的就會方式就是，租給別人，就是類似當外地的人做一些民宿，什麼觀光的部分，所以其實綠島現在，當然是戶籍綠島鄉四千多人，那戶籍的人口當然就是有外力什麼，因為這邊綠島有一些的福利的部分，所以有一些都是戶籍在人不在的部分。那這幾年當中，其實發展就是觀光的事業，那年輕人當然是有可能有回流的這個部分，這是綠島的一些狀況是這個部分。']
# 綠島土生土長長學完回來公費生回到綠島衛生所服務這樣子經快30年了回來工作長我國中外到屏東唸書然後之學成之後再回綠島服務這樣子衛生舊棟然後有新建我見過大樓107才落成這樣子醫療這幾年局政府偏鄉蠻重視醫療設備馬偕協助這是綠島提供醫療地方盡量補足這樣子109之後開始遠距醫療平常沒皮膚科科別眼科那一塊心臟這樣子皮膚科耳鼻喉科納進眼科補足科別平常這樣子科別那民眾遊客潛水耳鼻喉科潛水耳朵這一塊夏天蠻這一塊那皮膚海上話眼科話採購新儀器眼底鏡什麼大部分時沒辦法話轉診臺灣過這樣子醫療緊急後送相關SOP空中轉診這一塊海巡這一塊綠島醫療慢慢這樣子那當然這是居民這樣講農業時代漁業時代在後面這幾10年觀光綠島鄉觀光事業那當然綠島人口模式上會改變老人家年輕生病臺灣會小孩子年輕做生意時沒辦法照顧那有生病了辦法照顧送到臺東安養機構那有舉家遷出臺東臺東去了方式租給類似當外地民宿觀光綠島現戶籍綠島鄉四千多那戶籍人口外力綠島福利戶籍這幾年發展觀光事業那年輕人回流這是綠島狀況
# ['因為我那時候是公費生，因為其實我父母親也是在綠島，其實現在我們N4所內的人，大部分也都是應該算是臺東綠島兩邊跑，因為我們就是類似，居住都兩邊的，大部分都臺東都也有家，這是綠島的一個很比較不一樣的地方，就是我剛剛講的，在綠島他有自己的產業嘛，就是以前土生土長的那可是就是說經紀商和臺東，因為有時候小孩子就學或者是工作上面臺東，一定會買房子。這樣子，因為有買房的住宿的問題，所以大家不管房子是中古或任何的，其實大家綠島人在臺東已經買房子，就是應該算是比較方便。因為像有的人就是早上出去或隔天他辦事情臺東就完了，隔天就回來，其實交通上綠島算是，天氣很好的時候其實都還OK這樣子的部分，那我是因為我們服務會來，這也是自己的家鄉。對，所以就是想說在綠島。', '我們那時候才3年就可以了，可是一來因為工作就是也是自己的家鄉，然後對自己的工作上其實也是我其實還蠻喜歡的，就是自己的家鄉，對就這樣子就是一直服務下去就是做了這樣子，那當然就是說真的誒。 把我們的醫療就我當然是以醫療跟這邊我能夠做的，我們就盡量去去做，就像我們乳攝車，不管怎麼困難局也幫我們就是把那臺車運進來，綠島的能夠一次做完這樣子。 ']
# 公費生父母親也綠島其實現N4所內大部分算是臺東綠島兩邊跑類似居住兩邊大部分臺東有家這是綠島地方我剛剛講綠島產業土生土長經紀商和臺東小孩子就學工作臺東買房子這樣子買房住宿房子中古綠島臺東經買房子算是早上隔天他辦臺東完了隔天回來交通上綠島算是天氣實都還OK這樣子服務會這也家鄉想綠島才年了工作家鄉然後對工作還蠻喜歡家鄉這樣子服務了這樣子那當然誒醫療醫療盡量乳攝車困難局幫臺車運綠島完這樣子
# ['就是乳房攝影車，就是我們5月份也會把這臺用到綠島。他就是應該就是居民婦女的預防保健，我們要注重，就是一些公衛的那些任何我們基本上都是在做的，然後另外一面是也是醫療緊急醫療那一塊的這樣子。我們的衛生所做的就是應該算是綠島的大大小小出生任何的我們衛生所都會基本上都是管到的。', '對，就是想說我所做的東西能夠做，就是幫其實就是綠島的鄉民就是自己的一些相關的一些親戚朋友的的那個，這是我的想法，就是我能夠做的是盡量做我們維護的這一塊的部分，對不對？就像那時候疫情的關係，其實我們島真的是居民大家都也是怕外來什麼，可是我就覺得說，其實我們鄉鎮施打疫苗是最高的，因為大家就是會痊癒的，就是說疫苗這邊因為第一也是有觀光事業的問題，大家就說當然保護自己，你才有辦法做這個部分，所以其實我們這邊的大家的意願打這個疫苗，其實是還蠻踴躍的的部分這樣子。']
# 乳房攝影車月份臺用到綠島居民婦女預防保健注重公衛然醫療緊急醫療一塊這樣子衛生算是綠島大大小小出生衛生管到想幫其實綠島鄉民相關親戚朋友這是想法盡量維護這一塊疫情的關係我們島居民怕外來鄉鎮施疫苗痊癒疫苗第一觀光事業保護才辦法意願疫苗還蠻踴躍的這樣子
# ['其實困難，就像講說你醫療，因為有時候是天候的因素會影響，就像東北季風的時候，就是停船停飛，那就像我講說，萬一民眾要就是比喻說緊急狀況，可是因為風向的問題，基本上卡在這邊。其實我們的心也會覺得很擔心，因為這個是一個生命或是什麼，就是我們盡量就是說天氣其實心裡都是一直在祈禱的，這種事就是希望說，能夠順利插在一個風向之後，民眾的生命安全上是安全的好，這樣真的可是這樣的碰著麼久算是都還好就是可以去應付。', '東北季風就是我們綠島這邊會很很巧的。', '因為冬天來真的你飛機跟船曾經會停飛，就像類似颱風的那種狀態，可是你萬一就是緊急後送的時候，直升機有安全性上的問題，對你夜間盡量也是要考慮到這個問題，上面的機組的人員什麼那一些，就是白天就是等到，天氣OK了一段就是在半個小時一小時尖峰的時候，他們就在冒著生命危險就是要來幫病人。', '其實我真的很感謝這些大家各個機關各個團體的這些在幫綠島的這一塊的部分這樣子，這是我們的一些有困境，就像還有一個就是說像我們因為我們的衛生所就是環境，我們地不是很大，當然我們講說就是專門就是能夠坐收，像綠島有一些的人是洗腎，可是真的沒辦法，他都變成他居住在臺灣，除非他是父母自己洗的，可是有的人會安全疑慮，有的還是會說用血液上他們就住在臺東的部分，所以我才講說年老有一些身體狀況的，基本上就是回到臺東，當然離島就是有很也是一個真的有很不便的，有一些地方還是不方便的，就是像冬天的時候腳痛一定會受影響，我想那些部分，那你夏天這段期間，除非是颱風天而已，其實我覺得有一些的地方就是還蠻正常的部分。', '他基本上請海巡署的船，可是就是變成護理人員都要跟隨，其實我的能力上就是連我自己正式的人員才6個，我們自己聘一個護理人員7個，可是我們這樣子變成是我們衛生所的醫療是全年無休的，我的人都是這樣。類似你就是要排班的，隨時接到電話，你就是要出勤。其實這無形當中對大家都是會有點壓力的，可是因為在綠島沒辦法，你就是要這麼做。當然這是我們醫療這一塊的部分這樣子。', '第一，我們講真的就是只要類似像頭部外傷或者是溺水，就是他的生命已經危及到我們空中轉診的項目，我們就後送，就是因為我們這邊所做的醫療，有一定的範圍，有一些特殊的檢查，什麼哪一些的，還有一些治療住院方面的，基本上我們就會，這是這是很嚴重，才會直升機和海巡出去。那如果一般來看診醫師可能說它屬於慢性的，還不需要這樣子，可是可能某一個一些特殊的要再去做進一步的檢查，那我們就是一般我們這邊要開轉診單，那就是轉臺東，最大就是馬偕醫院嘛，就讓他去馬偕醫院這樣子，就是我們醫師的部分會作評估。', '讓他們轉就是到臺東這樣子去，或者是他們要到外縣就是高雄，哪裡其實都沒有限定他們，就是覺得轉診適合覺得OK了，這樣子對。', '醫師，我們現在有兩位我們編織上是有三位，可是現在就是還有一位，可是因為要等公費生，因為你想離島地方，有的人不見得會到離島來那個部分這樣子，因為在離島就是有很多還是有不便的地方，那他想覺得離綠島很遠，所以像公費是到現在也都還沒有，這個都要等衛福部的公費生，有沒有願意下來下鄉服務，因為我基本上醫師都是我就說全年無休嘛，你可以醫生不肯全部都一直在上班，不可能，所以就是要輪有三個，就是說基本上我平常會兩個醫生，然後一個能夠休息這樣子，有時候是你看兩個人只有一個休息一個站。萬一發生狀況就很多，像我們上個禮拜就發生很多的事情。上禮拜是那個蘭嶼綠島那個。還有，前面我們從禮拜四的時候，大概7號，就是突發有這邊的一些監獄狀況呢，就是發現就已經那個了，然後接著又有車禍的，但那又後送出去也有，就是一些相撞的問題，然後蘭嶼船的新聞報導又出來，那天也是下午，然後隔天就是太忙，有一個綠島的居民就是溺水的那部分，那天晚上隔天晚上，他們又忙，就是有後送可能發育新機的問題，就是一連串的這樣子。', '對，就一位醫師就會很忙，護理人員的部分也是會比較辛苦。', '我們現在一個家醫，一個是內科，對呀，平常禮拜六日的時候，馬偕他們會有分不同科別的進來的一些醫療團，他就禮拜六進來，可是要看飛機有沒有飛他才進來，然後禮拜天中午就回臺灣了。所以有一些特殊的專科診在假日的部分對，可是平常都是由我們醫生來做這個職業協助，就是來做這個動作這樣子，所以，上班時間上其實會比較長一點。那它所內在忙，然後又後送大家。雖然馬偕有聘護理人員，可是我們護理人員還是都下來支援了，發生甚麼事情大家都是互相幫忙的部分，這樣子。']
# 困難講說醫療天候因素影響東北季風停船停飛講說萬一民眾比喻緊急狀況風向卡在心擔心生命盡量天氣祈禱事希望順利插風向民眾生命安全碰著麼久算是還好應付東北季風綠島很巧冬天飛機船經會停飛類似颱風那種狀態萬緊急後送直升機有安全性夜間盡量機組人員什麼白天天氣OK了一段半個小時一小時尖峰生命危險要來幫病人感謝機關團體幫綠島這一塊這樣子這是困境衛生環境很大講說坐收綠島洗腎沒辦法居住臺灣父母洗人會疑慮血液住臺東才講說年老身體狀況回到臺東離島不便地方冬天腳痛會受影響想夏天這段期間颱風天地方還蠻請海巡署船變成護理人員能力連我正式人員才聘一個護理人員這樣子衛生醫療無休類似排班接到電話出勤這無形壓力綠島沒辦法這是醫療這一塊這樣子第一類似頭部外傷溺水生命危及空中轉診項目送醫療檢查治療住院這是這是才直升機和海巡看診醫師它屬慢性還不這樣子某一個進一步檢查開轉診單轉臺東馬偕醫院馬偕醫院這樣子醫師會作評估他們轉臺東這樣子外縣高雄沒限定轉診適合覺OK了這樣子醫師兩位編織三位一位公費生想離島地方不見離島這樣子離島不便地方想離綠島遠公費現還沒有衛福部公費生沒下鄉服務醫師無休醫生不肯上班要輪三個平常兩個醫生然後一個休息這樣子兩個休息站發生狀況上個禮拜發生上禮拜蘭嶼綠島禮拜四號突發監獄狀況發現了然後接車禍送出去相撞然後蘭嶼船新聞報導那天下午然隔天太忙綠島居民溺水那天晚上隔天晚上忙有後送發育新機一連串這樣子一位醫師忙護理人員辛苦家醫內科平常禮拜六日馬偕分科別醫療團禮拜六飛機沒飛才然後禮拜天中午回臺灣了專科診假日平常醫生職業協助動作這樣子上班時間實會較長一點它忙然後又後送馬偕聘護理人員護理人員支援了發生幫忙這樣子
# ['我在這邊長大的，我喜歡接觸人群，所以以前剛開始當教練。', '浮潛教練，然後帶客人們去出去玩去。夜觀阿，然後環島這些，所以本來就要客人他們都去住，就找找住的地方給他們住，所以我覺得這樣子，我覺得好像沒有跟客人的比較深入一點，沒有自己的客群，所以我就想要開自己的民宿，對然後就就找到這個公館村這地方，我本來是住南寮。Speaker1:', '老闆在嗎？', '燃料，另外。', '因為開自己有一個民宿就可以跟客人比較可以互動，然後就他們想要過來這邊聊天就就都可以。', '這邊開大概11年。', '對就小民宿，但我們對面有套房，這邊是雅房。就是背包，背包是住這邊，然後套房我們另外一棟是在對面棟是套房的，所以就是套房。大概是這樣子。 然後就又本來就在浮潛潛水那浮潛然後，現在就有潛水也有潛水點。', '中間有出去，隔兩三年而已，大概是25歲的時候。28出去，然後30歲的時候又回到綠島，出去本來就設定出去幾年沒有沒有一直要待在臺灣的，所以就出去完之後，就就想要回來綠島這裡。', '沒有設定要在臺灣待多久。', '就最終還是會回到綠島。', '沒有，我就喜歡水啊，然後喜歡海，然後在這裡比較自在跟臺灣。臺灣工作關係不一樣，就這裡比較自由一點。', '抽水機在工廠裡面，然後抽水機安裝，然後家樂福也有去過。然後本來是更早期是軍人，就當軍人當了5年。', '對，但是那個就我覺得我持續當下去的話，可能會變負債更多。', '軍中的同事，然後常常都會出去玩哦，對，所以就會花比較多。', '然後就想說就退休吧。這個計畫是就關於綠島，然後社會環境生態這些不同的']
# 長喜歡接觸人群剛開始當教練浮潛教練然後帶客人出去玩夜觀然後環島本來客人住找找住地方給他住我覺這樣子我覺好像客人一點客群想要開民宿對然找到公館村地方我本來住南寮Speaker1老闆燃料開民宿客人互動然後就想要聊天開11年民宿對面套房雅房背包背包住然套房一棟面棟套房套房這樣子然後就本來浮潛潛水浮潛然潛水潛水點隔兩三年25歲28然30歲回到綠島本來設定幾年臺灣的完想要回來綠島設定臺灣待多久最終回到綠島喜歡水然後喜歡海然後在臺灣臺灣工作關係自由一點抽水機在工廠然抽水機安裝然後家樂福去過然後本更早期軍人當軍人當了年持續當話會變負債更軍中同事然出去玩就會花然後就想退休計畫就關綠島然後社會環境生態
# ['之前應該都是比較生態類比較多海裡面或者是歷史。']
# 生態類海裡面歷史
# ['昆蟲應該比較少，但植物應該比較多一點，昆蟲就一兩種，是特別的很。', '綠島算是我的什麼？是像我的家。', '我們這就是所有東西都在這裡，然後家人也都在這裡啊，然後綠島就賺錢的方式，近期也是多多都在這裡，呃，就出去外面之後總會想到回到綠島，對就像像我就去臺東，可能就短暫的出去，然後就很想又回到綠島這裡來。']
# 昆蟲少植物一點昆蟲兩種特別綠島算是家然家人然後綠島賺錢方式近期外面之後總會想到回到綠島臺東短暫然後就想回到綠島
# ['沒有，就是都習慣了，但在這裡的話我取生活方式想要吃東西，我也就都可以去海邊，或者就是很早就隨便。我就不會餓到在綠島，如果你在生在這邊生活的話，簡簡單單的生活只是近期，這近近幾年來是綠島消費能力消費的需要更多錢，就每一餐或者是什麼就是就好像原物料都都比較漲價這樣。', '這個不像以前，然後就你隨便去吃的東西，可能100多塊就可以了，但現在沒有，現在大概都要300、500。', '對就是很奇怪，就是真相是甚麼我也不知道，為什麼會這樣？可能就很多很多有些是外來的人，他進來這邊生活，然後他可能是一間店，然後往比較優質一點，或者是網紅店，然後只要網紅有加持過，所以就很多店家就慢慢的跳跳高。但我不相信這這些東西。就是食材本來就是很貴，應該不太可能，但吃的東西就真的這麼貴。', '對啊，你們應該常常出去吃的東西。', '要特定有幾間的，真的就比較便宜。', '假設二十間，應該只有兩成是便宜，大概八成是很貴，你就是要花到一定的價錢才能吃到，吃到飽足感的東西。', '我們都是自己吃的，但是有偶爾會出去外面消費一下。', '對對。', '野菜也有竹筍，就採竹筍，然後我偶爾下雨天的時候會，夏天當然會比較多啦，就是也有水果也有。', '芭樂，然後然後有一個像像懶人的東西。', '人家讀大葉山欖。啊，綠島的會比較好吃一點。', '山豬肉是蘭嶼樹騎。', '大葉山欖比較比較大，可以到那麼大，那些蘭嶼樹騎只有一個。', '大葉山欖吃起來像酪梨。', '外面有一層皮，然後把它剝掉。', '就一樣是綠色，但是酪梨他會變到紅色，他會有整顆爛掉的時候就開始。', '對面吧，還是我正門口。', '不會，Speaker2:', '我差點都死在水裡，很熱，我全身四肢都麻了。', '你有潛水嘛？', '啊，哦，所以那你也是中研院裡面的人。', '偶爾上島而已。']
# 習慣了話我取生活方式想要吃海邊早就隨便餓綠島生生活話簡簡生活近期這近近幾年綠島消費能力消費更錢一餐好像原物料漲價然後就隨便吃100多塊了但現沒300500奇怪真相很多很多外來生活然後他一間店然後往優質一點網紅店然網紅有加持店家慢慢跳跳高這這些食材本來很貴不太可能吃貴吃特定幾間便宜假設二十間兩成便宜貴要花價錢吃吃飽足感吃偶爾會外面消費野菜竹筍採竹筍然後我下雨天夏天當然會水果芭樂然後然後有懶人讀大葉山欖綠島好吃一點山豬肉蘭嶼樹騎大葉山欖比蘭嶼樹騎大葉山欖吃酪梨外面一層皮然後把它剝掉綠色酪梨變到紅色他會整顆爛掉對面正門口Speaker2差點死水裡很熱全身四肢麻了潛水中研院上島
# ['工作跟居住，居住我沒有啦，其他人或許會有。然後工作沒有什麼困難，只是因為這邊的人大家都還蠻棒。我外地來的人對我你的工作沒有，以前可能剛開始創業的時候會有，但近期就不會了，但是剛開始創業人家也是會多幫助。綠島居民還是都會幫你就就是人情味很濃厚的地方，對所以他們就會很很願意幫助你。']
# 工作居住居住沒其他人許會然工作困難還蠻棒外地工作剛開始創業近期了剛開始創業綠島居民幫人情味濃厚地方
# ['可能你要搭建東西的時候，他就會很好心的過去然後幫你看，然後需要幫忙他看可能就會幫忙，或者會給你蓋房子的時候，你要規劃一個店，然後可能稍微給你，會給你意見。', '所以這邊開店應該不像蘭嶼，就是他們可能開店，他要設定的比較多一點，這邊只要土地租出去你有辦法租到，那就是就開店都是沒問題。', '哦，首先有很多超多超多超多的人進來這裡看。有些地方剛好是比較農地的地方，但是大家都是要生活啊，所以沒辦法，反正近可能是不要破壞到環境就這樣，但是外來的人可能很多外地來的。', '非正式的綠島居民，但是他們也算戶籍在這裡，所以他們算綠島居民。他們有些也很愛護綠島。很多都會環保意識啊，蠻重的。']
# 搭建好心然後幫然幫忙就會幫忙會給蓋房子規劃店然稍微給你會給意見開店不像蘭嶼開店設定一點土地租出去辦法租到開店沒超多超多超多地方農地地方生活沒辦法反正近破壞環境外來外地非正式綠島居民算戶籍算綠島居民愛護綠島環保意識蠻重
# ['生活上，我個人我們家是還好，所以別人我比較不太知道，但是真的是只要肯做就你肯動你肯做，其實都待在島上是不可能會餓到的。這裡的就業機率，這裡的這個生活方式跟臺灣不太一樣，生活臺灣就這麼多，所以你要賺的錢可能競爭力會比較大一點，那這邊的競爭力是比較小一點，雖然你是如果有很多假設民宿其他人也開100多間，但是這裡的容納就是那么少，所以大家分分大家有些孩子都分得到到了。那如果是跟之前去年比比較起來的話，去年是疫情，所以大家不能出國，所以整個島就。']
# 生活我個家還好太肯做肯動肯做島上餓就業機率生活方式臺灣不太生活臺灣就賺錢競爭力會一點競爭力一點假設民宿其他人開100多間容納那么少分分孩子分了去年比比話去年疫情出國整個島
# ['這是今年看到他說的，民宿都生意很好，生意很好，但今年就不太一樣，今年就是呃，有些店家好一點的店家，他會就分3年，今年今天可能我這裡有幾間店啊，明天可能你就有，因為不可能所有的客人都會到我們家。', '這次開放，但是他們是開放可以出國。', '其實在臺灣消費你要去東南亞，你要去菲律賓就東南呀，你要花2萬塊錢，你可以可能就去那邊了，你可以去五天。對在臺灣可能你2萬塊錢，大概也只有三四天吧。 臺灣的時候就是消費者費用比較高一點，相對的。']
# 這是民宿生意生意太店家一點店家他會分年幾間店明天客人家開放開放出國臺灣消費東南亞菲律賓東南花萬塊錢了五天臺灣萬塊錢三四天臺灣的消費者費用高一點
# ['那時候是非常少人。', '遊客很少。 對，就是就是沒有遊客，但是我們自己吃東西還是就是還蠻正常的，就去沒有其實那段時間沒有遊客對海裡面也是還不錯的。就只有海就其他島上的事，所以居民還是一樣，正常的作息就跟比較就可能沒有遊客之前就是這麼這麼的，就像冬天。', '對對對，沒有遊客，就像冬天。', '就回去，很少人，因為店家都不會在，沒什麼店家就可以這樣。所以就如果你現在是你有冬天來看11月的時候來。', '對，就是那個情況。其實島上的小店家，有些店家綠島居民的店家，他可能會開，通常都是麵店的人。 那如果網紅、網帥的店家，他們就會休息，因為沒有遊客，他們就賺不到錢。', '對大概大致上是這樣。關於是海的話，其實大環境的問題並不是人的問題，我們人綠島居民這些遊客少量而已啊。因為氣溫，它改變海裡面的東西，它就變了。 所以如果氣溫太高，他們來也是死掉，對吧？所以海裡面是比較沒什麼啊。', '噢，我沒有。', '沒有就是正常的綠島，就是山羌、果子狸、梅花鹿這些。這些東西然後也都正常了。']
# 那時候非常少遊客遊客吃還蠻沒那段時間遊客海裡面還不錯海島上事居民作息遊客冬天遊客冬天回去店家沒什麼店家你現冬天11月情況其實島小店家店家綠島居民店家會開麵店網紅網帥店家休息遊客賺不到錢關於是海話大環境問題並人綠島居民遊客少量氣溫它改變海裡面它變了氣溫太高死掉海裡面沒什麼噢沒綠島山羌果子狸梅花鹿東西然了
# ['臺灣跟綠島嗎？', '臺灣，你可能去吃東西的選擇性比較高啦，然後玩樂的也比較多一點，綠島玩樂就是玩水。大部分是玩水，然後會去山上。 山上可能就是山上走路過山古道這些。 這城市當然就是像我去城市，可能就可以去店家，你可以去百貨公司逛逛。對那這邊當然是沒有這些東西，一個是自然的，一個是人為的，差別在這。']
# 臺灣跟綠島臺灣吃選擇性比高然後玩樂一點綠島玩樂玩水大部分玩水然後會山上山上山上走路過山古道城市城市店家百貨公司逛逛沒自然差別
# ['我沒有找新的，新的就會去，有一些溪會去。', '遊客不一定都知道，就是綠島，真的裡面蝦子也會有了，就會有螺，然後那個螺是可以炒可以吃的。溪就真的是遊客就不可能會去的。', '不只，流麻溝主要的，但是他是水庫的，他就不算溪。所以這個流麻溝算水庫，那如果溪的話，是要往山上一點，你要看說要到睡美人地方會有一條，然後再從我們這邊上去之後主要是在這一區啊，因為這一區的水源比較多，然後又一條它的就是水庫的上緣，我們會去水庫的上緣那一邊。 那個蝦子叫過山蝦，所以他就會比較大型，然後他真的這麼大隻，晚上才會出來，就對那個蝦子都晚上，我們看到他眼睛。', '晚上才抓到他們，白天他們都躲起來。', '這邊吃的比較鹹一點，然後綠島居民，居民們吃的比較鹹。', '那媽媽煮的還可以，你吃那間算比較便宜。', '比其他。', '中寮的店家就非修多*23:52，跟那個太陽光。', '太陽光，你對自己一個人吃大概只有吃，如果吃那個麵就吃一個麵，可能就飽了。大概還不到100，那個其他店家你要吃一個餐就要300塊，加個飲料你大概400塊。', '那幾間店你吃了跟另外一間，大概就是一百塊就可以搞定一餐。', '在地人修，我們喜歡有幾幾樣的傳統料理，就花生做的東西，花生製品還有魚製品，魚可能會做鹹的，就是醃製過的魚，對這邊就比較喜歡。', '因為主要他鹹嘛，然後配飯的話，就魚就單純就他就可以配一碗飯真的是比較鹹一點。', '青菜現在這裡會有地瓜葉龍鬚菜，夏天前會有這陣子會有。 夏天他完全就會死掉了，龍鬚菜死掉了。還有高麗菜也是特地的南瓜胡瓜，還有那個什麼菠菜也有。', '這邊馬路的地方你都看不到田地，但是後面全部都有田。', '然後就在南寮的南寮區域裡面沒有田，但是在再過去一點石郎的位置就會有田地。', '沒有，是平的田。你從……', '搞那邊過來，在斜坡上去就可能公館村，然後就看到他後面全部都是田。', '這邊的公館圓圈的居民種了很多。', '那邊本來都是田，但是現在就大量的外來居民進來之後，那邊就開慢慢開發。 對不然只是沒有，那邊都是田的喔。綠島會種花生啦，還有地瓜。']
# 沒找新新溪會遊客綠島蝦子了螺然後那個螺炒吃溪遊客只流麻溝水庫不算溪流麻溝算水庫溪話山上一點睡美人地方會有一條然後再這一區這一區水源然一條它水庫上緣水庫緣蝦子過山蝦大型然後他隻晚上才蝦子晚上眼睛晚上才抓白天躲吃鹹一點然後綠島居民居民吃鹹那媽媽煮的還吃那間算便宜中寮店家非修多2352太陽光太陽光吃吃吃麵吃麵飽了不到100店家吃餐300塊加個飲料400塊那幾間店吃了一間一百塊搞定一餐地人修喜歡幾幾樣傳統料理花生花生製品魚製品魚鹹醃製魚喜歡鹹然後配飯話就魚配一碗飯鹹一點青菜這裡會地瓜葉龍鬚菜夏天前會這陣子夏天死掉了龍鬚菜死掉了高麗菜特地南瓜胡瓜菠菜馬路地方看不到田地面田然後就南寮南寮區域沒田一點石郎位置田地平田搞斜坡公館村然後就他後面全部都是田公館圓圈居民種了本來田外來居民開慢慢開發田喔綠島會種花生地瓜
# ['主要以前的主要食物是花生。', '花生也會做一道菜，花生就用果汁機把它打成粉狀的時候，然後綠島人叫它搗塗*27:20。本來就是你可以加了水之後，他就像豆漿。', '他的會吃那個渣，然後他就吃起來是甜的。', '對他就撈起來，他也可以煎，煎就變芡粿了。那如果他加水進去，然後再加點高麗菜，又或者是再加點綠島居民會加木瓜。', '木瓜，生的木瓜。', '甜的，那個是那個味道，他不用加太多的糖，他就是甜的。所以那個這就叫搗塗。', '只有這個喔。', '真的太多了，真的，嗯。', '對，那個是他做出來的時候，花生先做花生豆腐，他會先擠呀，擠完之後，然後他就會有渣渣的東西，那個渣就可以來做芡粿，所以花生的渣，那他是先煉油，煉油之後查可以做成豆腐，可以做成豆漿，豆漿完之後，如果其他渣你可以使用。', '不是不是。', '可以可以。']
# 食物花生花生一道菜花生果汁機把它打成粉狀然後綠島它搗塗2720本來加了水豆漿吃渣然後他吃甜撈煎煎變芡粿了加水然後再加點高麗菜加點綠島居民會加木瓜木瓜生木瓜甜味道不用加太多糖甜這就搗塗喔太多了做出花生先花生豆腐他會先擠擠完然後他渣渣渣芡粿花生渣先煉油煉油之後查做成豆腐做成豆漿豆漿完渣

# %%
import numpy as np
from scipy.spatial.distance import pdist, squareform
from collections import defaultdict

chunk_embeddings = json.load(open('result/chunk_embeddings/all.json', 'r'))
embeddings = [chunk_embeddings[id]['embedding'] for id in chunk_embeddings]
embeddings = [[0 for _ in range(1536)] if embedding == "No content" else embedding for embedding in embeddings]
ids = [chunk_embeddings[id]['id'] for id in chunk_embeddings]
embeddings = np.array(embeddings)
pairwise_distances = pdist(embeddings, metric='cosine')
distance_matrix = squareform(pairwise_distances)

# %%
for row_index in range(len(distance_matrix)):
    all_distances = distance_matrix[row_index]
    distances_grouped = defaultdict(list)
    for id_index in range(len(all_distances)):
        id = ids[id_index]
        interviewee_id = id.split("_")[0]
        distances_grouped[interviewee_id].append(all_distances[id_index]) 
    for interviewee_id, distances in distances_grouped.items():
        avg_distance = np.mean(distances)
        print(ids[row_index], interviewee_id, 1-avg_distance)
    print("---------------------------------")

# %%
def conversation_to_string(conversation):
    res = ""
    for message in conversation:
        speaker_flag = message['speaker']
        content = message['content']
        if speaker_flag == 0:
            speaker = 'Interviewee'
        else:
            speaker = 'Interviewer'
        res += f"{speaker}: {content}\n"
    return res
def prompt_connection(c1, c2):
    messages = [
        {
            "role": "system",
            "content": """
            You are a conversation similarity measurer. 
            The user will give you two conversations, first, decide if they about similar topics.
            If they are, summarize the topic in one phrase.
            Otherwise, reply with "Not similar".
            Reply concisely with one phrase in Traditional Chinese.
            """
        },
        {
            "role": "user",
            "content": c1
        },
        {
            "role": "user",
            "content": c2
        }
    ]
    return chatgpt(messages)

# %%
chunks = json.load(open('../data/result/chunk_embeddings/1103/all_chunks.json'))
chunk_dict = {chunk['id']: chunk for chunk in chunks}
chunk_similarities = json.load(open('../data/result/chunk_embeddings/1103/chunk_similarities.json'))
for c1, c2, sim in chunk_similarities:
    if sim > 0.9:
        conversation1 = conversation_to_string(chunk_dict[c1]['conversation'])
        conversation2 = conversation_to_string(chunk_dict[c2]['conversation'])
        print(conversation1)
        print(conversation2)
        res = prompt_connection(conversation1, conversation2)
        print(res)
        break

# %%
def query_time(file_name):
    messages = [
        {
            "role": "system",
            "content": """
            You are a time extractor. 
            The user will give you a report titles, your job is to extract the time of the report from the title.
            Reply with the following JSON format:
            {{
                'year': 2021,
                'month': 12,
                'day': 31
            }}
            """
        },
        {
            "role": "user",
            "content": file_name
        }
    ]

    return request_gpt4(messages, response_format="json")
def extract_report_time(report_files):
    for report_file in report_files:
        time = query_time(report_file)
        report_data = json.load(open(report_file))
        report_data['time'] = time
        print(report_file)
        print(time)
        save_json(report_data, report_file)
import glob
report_files = glob.glob('../data/raw/reports/representative_proposals/json/*.json')
extract_report_time(report_files)

# %%
for report_files in glob.glob('../data/raw/reports/representative_proposals/json/*.json'):
    report_data = json.load(open(report_files))
    file_name = report_files.split('/')[-1].split('.')[0]
    report_embedding_file = f'../data/result/proposal_embeddings/{file_name}.json'
    report_embedding = json.load(open(report_embedding_file))
    report_embedding['time'] = report_data['time']
    save_json(report_embedding, report_embedding_file)

# %%
for report_files in glob.glob('../data/result/proposal_embeddings/*.json'):
    report_data = json.load(open(report_files))
    time = json.loads(report_data['time'])
    print(time)
    report_data['time'] = time
    save_json(report_data, report_files)
# Out:
# {'year': 2021, 'month': 12, 'day': 2}
# {'year': 2020, 'month': 11, 'day': 24}
# {'year': 2021, 'month': 12, 'day': 2}
# {'year': 2021, 'month': 12, 'day': 2}
# {'year': 2020, 'month': 6, 'day': 30}
# {'year': 2020, 'month': 8, 'day': 3}
# {'year': 2021, 'month': 4, 'day': 12}
# {'year': 2021, 'month': 12, 'day': 2}
# {'year': 2020, 'month': 6, 'day': 30}
# {'year': 2021, 'month': 5, 'day': 3}
# {'year': 2020, 'month': 10, 'day': 14}
# {'year': 2020, 'month': 11, 'day': 24}
# {'year': 2021, 'month': 8, 'day': 19}
# {'year': 2020, 'month': 12, 'day': 23}
# {'year': 2021, 'month': 8, 'day': 19}
# {'year': 2021, 'month': 8, 'day': 19}
# {'year': 2021, 'month': 5, 'day': 3}
# {'year': 2020, 'month': 6, 'day': 30}
# {'year': 2021, 'month': 12, 'day': 2}
# {'year': 2020, 'month': 10, 'day': 14}
# {'year': 2020, 'month': 8, 'day': 3}
# {'year': 2021, 'month': 12, 'day': 2}
# {'year': 2021, 'month': 4, 'day': 12}
# {'year': 2021, 'month': 4, 'day': 12}
# {'year': 2021, 'month': 5, 'day': 3}
# {'year': 2021, 'month': 5, 'day': 3}
# {'year': 2021, 'month': 8, 'day': 19}
# {'year': 2021, 'month': 8, 'day': 19}
# {'year': 2020, 'month': 11, 'day': 24}
# {'year': 2021, 'month': 12, 'day': 2}
# {'year': 2021, 'month': 12, 'day': 2}
# {'year': 2020, 'month': 12, 'day': 23}
# {'year': 2021, 'month': 9, 'day': 13}
# {'year': 2022, 'month': 3, 'day': 9}
# {'year': 2021, 'month': 12, 'day': 2}
# {'year': 2021, 'month': 9, 'day': 13}
# {'year': 2021, 'month': 12, 'day': 2}
# {'year': 2020, 'month': 12, 'day': 23}
# {'year': 2021, 'month': 8, 'day': 19}
# {'year': 2021, 'month': 8, 'day': 19}
# {'year': 2021, 'month': 5, 'day': 3}
# {'year': 2021, 'month': 4, 'day': 12}
# {'year': 2020, 'month': 10, 'day': 14}
# {'year': 2021, 'month': 12, 'day': 2}
# {'year': 2021, 'month': 5, 'day': 3}
# {'year': 2022, 'month': 3, 'day': 9}
# {'year': 2022, 'month': 3, 'day': 9}
# {'year': 2021, 'month': 12, 'day': 2}
# {'year': 2020, 'month': 11, 'day': 24}
# {'year': 2021, 'month': 12, 'day': 2}
# {'year': 2020, 'month': 12, 'day': 23}
# {'year': 2021, 'month': 9, 'day': 13}
# {'year': 2021, 'month': 5, 'day': 3}
# {'year': 2022, 'month': 3, 'day': 9}
# {'year': 2020, 'month': 12, 'day': 23}
# {'year': 2021, 'month': 8, 'day': 19}
# {'year': 2021, 'month': 4, 'day': 12}
# {'year': 2021, 'month': 8, 'day': 19}
# {'year': 2021, 'month': 8, 'day': 19}
# {'year': 2020, 'month': 6, 'day': 30}
# {'year': 2020, 'month': 8, 'day': 3}
# {'year': 2020, 'month': 10, 'day': 14}
# {'year': 2020, 'month': 8, 'day': 3}
# {'year': 2020, 'month': 10, 'day': 14}
# {'year': 2021, 'month': 5, 'day': 3}
# {'year': 2021, 'month': 12, 'day': 2}
# {'year': 2021, 'month': 4, 'day': 12}
# {'year': 2021, 'month': 8, 'day': 19}
# {'year': 2020, 'month': 11, 'day': 24}
# {'year': 2020, 'month': 6, 'day': 30}
# {'year': 2020, 'month': 11, 'day': 24}
# {'year': 2021, 'month': 5, 'day': 3}
# {'year': 2020, 'month': 6, 'day': 30}
# {'year': 2021, 'month': 8, 'day': 19}
# {'year': 2021, 'month': 8, 'day': 19}
# {'year': 2020, 'month': 12, 'day': 23}
# {'year': 2020, 'month': 10, 'day': 14}
# {'year': 2021, 'month': 12, 'day': 2}
# {'year': 2021, 'month': 12, 'day': 2}
# {'year': 2020, 'month': 8, 'day': 3}
# {'year': 2021, 'month': 12, 'day': 2}
# {'year': 2021, 'month': 5, 'day': 3}
# {'year': 2022, 'month': 3, 'day': 9}
# {'year': 2020, 'month': 6, 'day': 30}
